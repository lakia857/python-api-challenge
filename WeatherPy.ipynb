# %% [markdown]
# # WeatherPy
#
# ---
#
# ## Starter Code to Generate Random Geographic Coordinates and a List of Cities

# %%
# Dependencies and Setup
import matplotlib.pyplot as plt
import pandas as pd
import numpy as np
import requests
import time
from scipy.stats import linregress

# Impor the OpenWeatherMap API key
from api_keys import weather_api_key

# Import citipy to determine the cities based on latitude and longitude
from citipy import citipy

# %% [markdown]
# ### Generate the Cities List by Using the `citipy` Library

# %%
# Empty list for holding the latitude and longitude combinations
lat_lngs = []

# Empty list for holding the cities names
cities = []

# Range of latitudes and longitudes
lat_range = (-90, 90)
lng_range = (-180, 180)

# Create a set of random lat and lng combinations
lats = np.random.uniform(lat_range[0], lat_range[1], size=1500)
lngs = np.random.uniform(lng_range[0], lng_range[1], size=1500)
lat_lngs = zip(lats, lngs)

# Identify nearest city for each lat, lng combination
for lat_lng in lat_lngs:
    city = citipy.nearest_city(lat_lng[0], lat_lng[1]).city_name
    
    # If the city is unique, then add it to a our cities list
    if city not in cities:
        cities.append(city)

# Print the city count to confirm sufficient count
print(f"Number of cities in the list: {len(cities)}")
# Out:
# Number of cities in the list: 593

# %%
cities
# Out:
# ['afaahiti',
#  'papatowai',
#  'aasiaat',
#  'lhasa',
#  'port elizabeth',
#  'kalashnikovo',
#  'blackmans bay',
#  'anadyr',
#  'jamestown',
#  'kamaishi',
#  'ushuaia',
#  'totness',
#  'waitangi',
#  'ondjiva',
#  'la passe',
#  'remire-montjoly',
#  'olinda',
#  'suva',
#  'adamstown',
#  'invercargill',
#  'casablanca',
#  'bethel',
#  'margaret river',
#  'port-aux-francais',
#  'saratamata',
#  'tolanaro',
#  'newman',
#  'klyuchi',
#  'boa vista',
#  'minas de marcona',
#  'grytviken',
#  'trosa',
#  'queenstown',
#  'bredasdorp',
#  'bafq',
#  'iskateley',
#  'kankaanpaa',
#  'benjamin hill',
#  'yangor',
#  'sola',
#  'salinera colan',
#  'aykhal',
#  'puerto natales',
#  'frutal',
#  'ragana',
#  'dapa',
#  'codrington',
#  'chonchi',
#  'yeppoon',
#  'enumclaw',
#  'alofi',
#  'levuka',
#  'tiksi',
#  'charters towers',
#  'georgetown',
#  'gulf breeze',
#  'mount gambier',
#  'edinburgh of the seven seas',
#  'winnemucca',
#  'cosesti',
#  'iqaluit',
#  'lihue',
#  'loreto',
#  'yellowknife',
#  'wailua homesteads',
#  'antigonish',
#  "st. john's",
#  'tazacorte',
#  'stanley',
#  'tilisarao',
#  'sunne',
#  'izberbash',
#  'hawaiian paradise park',
#  'bilibino',
#  'susuman',
#  'jawf al maqbabah',
#  'tsagan aman',
#  'kuta',
#  'port mathurin',
#  'olonkinbyen',
#  'ribeira grande',
#  'udachny',
#  'utrik',
#  'amalapuram',
#  'lata',
#  'asekeyevo',
#  'madzhalis',
#  'atafu village',
#  'de soto',
#  'lethem',
#  'bardai',
#  'rongelap',
#  'puerto san carlos',
#  'ludington',
#  'hadibu',
#  'sur',
#  'coquimbo',
#  'fortuna',
#  'taiohae',
#  'santa terezinha',
#  'tazovsky',
#  'dudinka',
#  'flying fish cove',
#  'sandnessjoen',
#  'tsengel',
#  'kokstad',
#  'albany',
#  'vingt cinq',
#  'kapuskasing',
#  'la paz',
#  'fray luis beltran',
#  'sao paulo de olivenca',
#  'montpelier',
#  'howrah',
#  'charcas',
#  'itumba',
#  'saipan',
#  'college',
#  'qorveh',
#  'houlton',
#  'port douglas',
#  'chimoio',
#  'itamaraca',
#  'grand falls-windsor',
#  'praia da vitoria',
#  'nybro',
#  'ahau',
#  'al ghayzah',
#  'brigantine',
#  'bambanglipuro',
#  'revda',
#  'weno',
#  'hotan',
#  'west island',
#  'prien',
#  'lamu',
#  'mata-utu',
#  'avarua',
#  'itaituba',
#  'kununurra',
#  'brookings',
#  'bermejo',
#  'new norfolk',
#  'pemangkat',
#  'holualoa',
#  'zaozersk',
#  'isafjordur',
#  'kievka',
#  'san andros',
#  'plast',
#  'erdenet',
#  'sinop',
#  'dwarka',
#  'carnarvon',
#  'orumiyeh',
#  'usinsk',
#  'keflavik',
#  'sirte',
#  'vorkuta',
#  'daru',
#  'lysyye gory',
#  'hamilton',
#  'novogrudok',
#  'kerikeri',
#  'san patricio',
#  'ilulissat',
#  'talnakh',
#  'atamaria',
#  'saanen',
#  'kurumkan',
#  'whitehorse',
#  'nizhneudinsk',
#  'shache',
#  'puerto ayora',
#  'cockburn town',
#  'emerald',
#  'battagram',
#  'san luis de la loma',
#  'darwin',
#  'longyearbyen',
#  'fauske',
#  'vilyuchinsk',
#  'arraial do cabo',
#  'enewetak',
#  'tucumcari',
#  'vadso',
#  'kerteminde',
#  'argo',
#  'lorengau',
#  'badger',
#  'sitka',
#  'barakani',
#  'tosontsengel',
#  'urangan',
#  'puerto baquerizo moreno',
#  'north platte',
#  'rugaji',
#  'phalodi',
#  'fale old settlement',
#  'kourou',
#  'waddan',
#  'gangtok',
#  'ouellah',
#  'aleg',
#  'oriximina',
#  'vilyuysk',
#  "nar'yan-mar",
#  'sitia',
#  'hermanus',
#  'lompoc',
#  'gabu',
#  'touros',
#  'luderitz',
#  'broken hill',
#  'rakops',
#  'callao',
#  'fruita',
#  'tranovaho',
#  'constitucion',
#  'pauini',
#  'santanyi',
#  'xiaoshan',
#  'oranjemund',
#  'shagonar',
#  'nizhniy odes',
#  'galliano',
#  'ust-nera',
#  'luganville',
#  'uturoa',
#  'murun-kuren',
#  'blackburn south',
#  'nyurba',
#  'belorechensk',
#  'krasnyye baki',
#  'mwinilunga',
#  'binhe',
#  "ust'-ordynskiy",
#  'vorgashor',
#  'guerrero negro',
#  'pontes e lacerda',
#  'sao jose da coroa grande',
#  'huarmey',
#  'ancud',
#  'alexandria',
#  'tosno',
#  'amancio',
#  'mount pearl',
#  'caruthersville',
#  'khorramabad',
#  'laojunmiao',
#  'comodoro rivadavia',
#  'kodiak',
#  'ryotsu-minato',
#  'ceeldheer',
#  'port lincoln',
#  'tevriz',
#  "medvezh'yegorsk",
#  'rusape',
#  'hammerfest',
#  'mbaiki',
#  'nampula',
#  'leer',
#  'capdepera',
#  'punta arenas',
#  'thompson',
#  'kenai',
#  'paracuru',
#  'quixeramobim',
#  'kayangel',
#  'bonthe',
#  'tomatlan',
#  'manokwari',
#  'pamandzi',
#  'ulety',
#  'katsuren-haebaru',
#  'pula',
#  'staroleushkovskaya',
#  'vydrino',
#  'howard springs',
#  'san antonio de pale',
#  'lerwick',
#  'antofagasta',
#  'la ronge',
#  'san jose del guaviare',
#  'colonia',
#  'chililabombwe',
#  'kazalinsk',
#  'tezu',
#  'ugoofaaru',
#  'egilsstadir',
#  'carutapera',
#  'cole harbour',
#  'pimentel',
#  'minab',
#  'polyarnyy',
#  'ola',
#  'prado',
#  'sinazongwe',
#  'yaren',
#  'tual',
#  'grimstad',
#  'manadhoo',
#  'saldanha',
#  'tres palos',
#  'bindura',
#  'cargados carajos',
#  'kishtwar',
#  'vanimo',
#  'yanbu',
#  'kharan',
#  'miyanoura',
#  'benalla',
#  'ponta delgada',
#  'peace river',
#  'magong',
#  'mejit',
#  'sechura',
#  'baotou',
#  'lebu',
#  'simanggang',
#  'saint-pierre',
#  'tura',
#  'basotu',
#  'strathmore',
#  'whitecourt',
#  'ca mau',
#  'kyren',
#  'devinuwara',
#  'jaboticabal',
#  'naantali',
#  'gumdag',
#  'tyup',
#  'tenno',
#  'severo-yeniseyskiy',
#  'gonzaga',
#  'bac lieu',
#  'constantia',
#  'vesele',
#  'sinabang',
#  'nadi',
#  'chadan',
#  'ennis',
#  'kingston',
#  'kizhinga',
#  'happy valley-goose bay',
#  'chernyshevskiy',
#  'palmer',
#  'plastun',
#  'qaqortoq',
#  'balta',
#  'kavaratti',
#  'san pedro pochutla',
#  'kudahuvadhoo',
#  'acarau',
#  "'ohonua",
#  'zheleznogorsk',
#  'dakhla',
#  'nikolayevsk-on-amure',
#  'awjilah',
#  'vila franca do campo',
#  'trincomalee',
#  'bealanana',
#  'guatire',
#  'thai nguyen',
#  'cabo san lucas',
#  'al khums',
#  'hinton',
#  'jua dos vieiras',
#  'machico',
#  'loushanguan',
#  'matlang',
#  'cururupu',
#  'villa gesell',
#  'neiafu',
#  'port augusta',
#  'iwon-up',
#  'nemuro',
#  'pasuquin',
#  'paramonga',
#  'nova sintra',
#  "nuku'alofa",
#  'bridgewater',
#  'miranda',
#  'santa maria',
#  'tralee',
#  'barmer',
#  'tremonton',
#  'camayenne',
#  'mercedes',
#  'meulaboh',
#  'mahibadhoo',
#  'nuuk',
#  'pukchil-lodongjagu',
#  'mao',
#  'ulsteinvik',
#  'aydin',
#  'porto novo',
#  'petropavlovsk-kamchatsky',
#  'wanning',
#  'chibougamau',
#  'rio preto da eva',
#  'chakari',
#  'gadzhiyevo',
#  'daigo',
#  'port alfred',
#  'westport',
#  'pacific grove',
#  'kembe',
#  'maragogi',
#  'makokou',
#  'as sulayyil',
#  'villanueva',
#  'jinxiang',
#  'ridder',
#  'machachi',
#  'warnsveld',
#  'iquique',
#  'port blair',
#  'impfondo',
#  'alotau',
#  'saint-philippe',
#  'gafsa',
#  'abatskoye',
#  'fort mcmurray',
#  'yermentau',
#  'khanty-mansiysk',
#  'tabou',
#  'isla mujeres',
#  'arinos',
#  'shingu',
#  'dongola',
#  "razdol'noye",
#  'khorugh',
#  'whakatane',
#  'dingzhou',
#  'baskale',
#  'ciudad lazaro cardenas',
#  'senador jose porfirio',
#  'al hazm',
#  'nishinoomote',
#  'albu kamal',
#  'kirakira',
#  'barysh',
#  'mermoz boabab',
#  'usogorsk',
#  'lloydminster',
#  'veraval',
#  'sokoni',
#  'dadonghai',
#  'garh maharaja',
#  'pembroke',
#  'bubaque',
#  'breckenridge',
#  "al 'alamayn",
#  'pisco',
#  'tanjung selor',
#  'guarapari',
#  'alamar',
#  'greymouth',
#  'conception bay south',
#  'saint john',
#  'walvis bay',
#  'eureka',
#  'beni mellal',
#  'gwanda',
#  'bandarbeyla',
#  'oelwein',
#  'jiangzi',
#  'sao vicente',
#  'qurayyat',
#  'ballesteros',
#  'buka',
#  'north elba',
#  'toliara',
#  'mitu',
#  'altai',
#  'tajiri',
#  'kuanda',
#  'coronel suarez',
#  'isangel',
#  'conneaut',
#  'eydhafushi',
#  'tursunzoda',
#  'balashikha',
#  'mountain home',
#  'cozumel',
#  'zabol',
#  'koshki',
#  'muscat',
#  'midar',
#  'serenje',
#  'kisangani',
#  'karratha',
#  'umarkot',
#  'smara',
#  'yelovo',
#  'bor',
#  'hihifo',
#  'portland',
#  'coahuayana de hidalgo',
#  'nguigmi',
#  'livingstone',
#  'east london',
#  'undurkhaan',
#  'gereshk',
#  'hirado',
#  'zaragoza',
#  'crane',
#  'torrevieja',
#  'matoury',
#  'santa rosa',
#  'izhmorskiy',
#  'afif',
#  'boende',
#  'rio grande',
#  'palikir - national government center',
#  'huaiyuan chengguanzhen',
#  'fort bragg',
#  'khunti',
#  'aq qayeh',
#  'grants pass',
#  'mount isa',
#  'zhanaozen',
#  'aragarcas',
#  'mont-tremblant',
#  'valparaiso',
#  'ouesso',
#  'selkirk',
#  "ves'yegonsk",
#  "ma'an",
#  'kilju',
#  'lakatoro',
#  'shortandy',
#  'labrador city',
#  'el porvenir',
#  'mugia',
#  'hamada',
#  'biloela',
#  "'ain el turk",
#  'beau vallon',
#  'zaysan',
#  'quelimane',
#  'cannonvale',
#  'herzliya pituah',
#  'ambovombe',
#  'tsiolkovskiy',
#  'kulia village',
#  'okhotsk',
#  'ahar',
#  'newark',
#  'kailua-kona',
#  'la palma',
#  'sarupathar',
#  'mirnyy',
#  'monrovia',
#  'feodosiya',
#  'camabatela',
#  'nelsonville',
#  'kidal',
#  'takoradi',
#  'concordia',
#  'bam',
#  'panchkula',
#  'wanxian',
#  'novo aripuana',
#  'taroa',
#  'phuthaditjhaba',
#  'noshiro',
#  'kokpekty',
#  'kone',
#  'thinadhoo',
#  'abbiategrasso',
#  'anicuns',
#  'taoudenni',
#  'salekhard',
#  'mazatlan',
#  'fort st. john',
#  'ta`u',
#  'aleksandrovsk-sakhalinskiy',
#  'el granada',
#  'fernandopolis',
#  'ujae',
#  'broome',
#  'geraldton',
#  'tarko-sale',
#  'island harbour',
#  'argostolion',
#  'alesund',
#  'berbera',
#  'tome acu',
#  'kingscliff',
#  'faya-largeau',
#  'barreirinha']

# %% [markdown]
# ---

# %% [markdown]
# ## Requirement 1: Create Plots to Showcase the Relationship Between Weather Variables and Latitude
#
# ### Use the OpenWeatherMap API to retrieve weather data from the cities list generated in the started code

# %%
# Set the API base URL

url = "http://api.openweathermap.org/data/2.5/weather?units=metric&appid=" + weather_api_key
#units = "metric"

# Build partial query URL
#query_url = f"{url}appid={weather_api_key}&units={units}&q="

# Define an empty list to fetch the weather data for each city
city_data = []

# Print to logger
print("Beginning Data Retrieval     ")
print("-----------------------------")

# Create counters
record_count = 1
set_count = 1

# Loop through all the cities in our list to fetch weather data
for i, city in enumerate(cities):
        
    # Group cities in sets of 50 for logging purposes
    if (i % 50 == 0 and i >= 50):
        set_count += 1
        record_count = 0

    # Create endpoint URL with each city
    city_url = url + "&q=" + city
    
    # Log the url, record, and set numbers
    print("Processing Record %s of Set %s | %s" % (record_count, set_count, city))

    # Add 1 to the record count
    record_count += 1

    # Run an API request for each of the cities
    try:
        # Parse the JSON and retrieve data
        city_weather = requests.get(city_url).json()

         # Parse out latitude, longitude, max temp, humidity, cloudiness, wind speed, country, and date
        city_lat = city_weather['coord']['lat']
        city_lng = city_weather['coord']['lon']
        city_max_temp = city_weather['main']['temp_max']
        city_humidity = city_weather['main']['humidity']
        city_clouds = city_weather['clouds']['all']
        city_wind = city_weather['wind']['speed']
        city_country = city_weather['sys']['country']
        city_date = city_weather['dt']

         # Append the City information into city_data list
        city_data.append({"City": city, 
                           "Lat": city_lat, 
                           "Lng": city_lng, 
                           "Max Temp": city_max_temp,
                           "Humidity": city_humidity,
                           "Cloudiness": city_clouds,
                           "Wind Speed": city_wind,
                           "Country": city_country,
                           "Date": city_date})

    # If an error is experienced, skip the city
    except:
        print("City not found. Skipping...")
        pass
# city_weather              
# Indicate that Data Loading is complete 
print("-----------------------------")
print("Data Retrieval Complete      ")
print("-----------------------------")
# Out:
# Beginning Data Retrieval
# -----------------------------
# Processing Record 1 of Set 1 | afaahiti
# Processing Record 2 of Set 1 | papatowai
# Processing Record 3 of Set 1 | aasiaat
# Processing Record 4 of Set 1 | lhasa
# Processing Record 5 of Set 1 | port elizabeth
# Processing Record 6 of Set 1 | kalashnikovo
# Processing Record 7 of Set 1 | blackmans bay
# Processing Record 8 of Set 1 | anadyr
# Processing Record 9 of Set 1 | jamestown
# Processing Record 10 of Set 1 | kamaishi
# Processing Record 11 of Set 1 | ushuaia
# Processing Record 12 of Set 1 | totness
# Processing Record 13 of Set 1 | waitangi
# Processing Record 14 of Set 1 | ondjiva
# Processing Record 15 of Set 1 | la passe
# Processing Record 16 of Set 1 | remire-montjoly
# Processing Record 17 of Set 1 | olinda
# Processing Record 18 of Set 1 | suva
# Processing Record 19 of Set 1 | adamstown
# Processing Record 20 of Set 1 | invercargill
# Processing Record 21 of Set 1 | casablanca
# Processing Record 22 of Set 1 | bethel
# Processing Record 23 of Set 1 | margaret river
# Processing Record 24 of Set 1 | port-aux-francais
# Processing Record 25 of Set 1 | saratamata
# City not found. Skipping...
# Processing Record 26 of Set 1 | tolanaro
# Processing Record 27 of Set 1 | newman
# Processing Record 28 of Set 1 | klyuchi
# Processing Record 29 of Set 1 | boa vista
# Processing Record 30 of Set 1 | minas de marcona
# Processing Record 31 of Set 1 | grytviken
# Processing Record 32 of Set 1 | trosa
# Processing Record 33 of Set 1 | queenstown
# Processing Record 34 of Set 1 | bredasdorp
# Processing Record 35 of Set 1 | bafq
# Processing Record 36 of Set 1 | iskateley
# Processing Record 37 of Set 1 | kankaanpaa
# Processing Record 38 of Set 1 | benjamin hill
# Processing Record 39 of Set 1 | yangor
# City not found. Skipping...
# Processing Record 40 of Set 1 | sola
# Processing Record 41 of Set 1 | salinera colan
# Processing Record 42 of Set 1 | aykhal
# Processing Record 43 of Set 1 | puerto natales
# Processing Record 44 of Set 1 | frutal
# Processing Record 45 of Set 1 | ragana
# Processing Record 46 of Set 1 | dapa
# Processing Record 47 of Set 1 | codrington
# Processing Record 48 of Set 1 | chonchi
# Processing Record 49 of Set 1 | yeppoon
# Processing Record 50 of Set 1 | enumclaw
# Processing Record 0 of Set 2 | alofi
# Processing Record 1 of Set 2 | levuka
# Processing Record 2 of Set 2 | tiksi
# Processing Record 3 of Set 2 | charters towers
# Processing Record 4 of Set 2 | georgetown
# Processing Record 5 of Set 2 | gulf breeze
# Processing Record 6 of Set 2 | mount gambier
# Processing Record 7 of Set 2 | edinburgh of the seven seas
# Processing Record 8 of Set 2 | winnemucca
# Processing Record 9 of Set 2 | cosesti
# Processing Record 10 of Set 2 | iqaluit
# Processing Record 11 of Set 2 | lihue
# Processing Record 12 of Set 2 | loreto
# Processing Record 13 of Set 2 | yellowknife
# Processing Record 14 of Set 2 | wailua homesteads
# Processing Record 15 of Set 2 | antigonish
# Processing Record 16 of Set 2 | st. john's
# Processing Record 17 of Set 2 | tazacorte
# Processing Record 18 of Set 2 | stanley
# Processing Record 19 of Set 2 | tilisarao
# Processing Record 20 of Set 2 | sunne
# Processing Record 21 of Set 2 | izberbash
# Processing Record 22 of Set 2 | hawaiian paradise park
# Processing Record 23 of Set 2 | bilibino
# Processing Record 24 of Set 2 | susuman
# Processing Record 25 of Set 2 | jawf al maqbabah
# Processing Record 26 of Set 2 | tsagan aman
# Processing Record 27 of Set 2 | kuta
# Processing Record 28 of Set 2 | port mathurin
# Processing Record 29 of Set 2 | olonkinbyen
# Processing Record 30 of Set 2 | ribeira grande
# Processing Record 31 of Set 2 | udachny
# Processing Record 32 of Set 2 | utrik
# Processing Record 33 of Set 2 | amalapuram
# Processing Record 34 of Set 2 | lata
# Processing Record 35 of Set 2 | asekeyevo
# Processing Record 36 of Set 2 | madzhalis
# Processing Record 37 of Set 2 | atafu village
# Processing Record 38 of Set 2 | de soto
# Processing Record 39 of Set 2 | lethem
# Processing Record 40 of Set 2 | bardai
# Processing Record 41 of Set 2 | rongelap
# Processing Record 42 of Set 2 | puerto san carlos
# City not found. Skipping...
# Processing Record 43 of Set 2 | ludington
# Processing Record 44 of Set 2 | hadibu
# Processing Record 45 of Set 2 | sur
# Processing Record 46 of Set 2 | coquimbo
# Processing Record 47 of Set 2 | fortuna
# Processing Record 48 of Set 2 | taiohae
# City not found. Skipping...
# Processing Record 49 of Set 2 | santa terezinha
# Processing Record 0 of Set 3 | tazovsky
# Processing Record 1 of Set 3 | dudinka
# Processing Record 2 of Set 3 | flying fish cove
# Processing Record 3 of Set 3 | sandnessjoen
# Processing Record 4 of Set 3 | tsengel
# Processing Record 5 of Set 3 | kokstad
# Processing Record 6 of Set 3 | albany
# Processing Record 7 of Set 3 | vingt cinq
# City not found. Skipping...
# Processing Record 8 of Set 3 | kapuskasing
# Processing Record 9 of Set 3 | la paz
# Processing Record 10 of Set 3 | fray luis beltran
# Processing Record 11 of Set 3 | sao paulo de olivenca
# Processing Record 12 of Set 3 | montpelier
# Processing Record 13 of Set 3 | howrah
# Processing Record 14 of Set 3 | charcas
# Processing Record 15 of Set 3 | itumba
# Processing Record 16 of Set 3 | saipan
# Processing Record 17 of Set 3 | college
# Processing Record 18 of Set 3 | qorveh
# Processing Record 19 of Set 3 | houlton
# Processing Record 20 of Set 3 | port douglas
# Processing Record 21 of Set 3 | chimoio
# Processing Record 22 of Set 3 | itamaraca
# Processing Record 23 of Set 3 | grand falls-windsor
# Processing Record 24 of Set 3 | praia da vitoria
# Processing Record 25 of Set 3 | nybro
# Processing Record 26 of Set 3 | ahau
# City not found. Skipping...
# Processing Record 27 of Set 3 | al ghayzah
# Processing Record 28 of Set 3 | brigantine
# Processing Record 29 of Set 3 | bambanglipuro
# Processing Record 30 of Set 3 | revda
# Processing Record 31 of Set 3 | weno
# Processing Record 32 of Set 3 | hotan
# Processing Record 33 of Set 3 | west island
# Processing Record 34 of Set 3 | prien
# Processing Record 35 of Set 3 | lamu
# Processing Record 36 of Set 3 | mata-utu
# Processing Record 37 of Set 3 | avarua
# Processing Record 38 of Set 3 | itaituba
# Processing Record 39 of Set 3 | kununurra
# Processing Record 40 of Set 3 | brookings
# Processing Record 41 of Set 3 | bermejo
# Processing Record 42 of Set 3 | new norfolk
# Processing Record 43 of Set 3 | pemangkat
# Processing Record 44 of Set 3 | holualoa
# Processing Record 45 of Set 3 | zaozersk
# Processing Record 46 of Set 3 | isafjordur
# Processing Record 47 of Set 3 | kievka
# Processing Record 48 of Set 3 | san andros
# City not found. Skipping...
# Processing Record 49 of Set 3 | plast
# Processing Record 0 of Set 4 | erdenet
# Processing Record 1 of Set 4 | sinop
# Processing Record 2 of Set 4 | dwarka
# Processing Record 3 of Set 4 | carnarvon
# Processing Record 4 of Set 4 | orumiyeh
# Processing Record 5 of Set 4 | usinsk
# Processing Record 6 of Set 4 | keflavik
# Processing Record 7 of Set 4 | sirte
# Processing Record 8 of Set 4 | vorkuta
# Processing Record 9 of Set 4 | daru
# Processing Record 10 of Set 4 | lysyye gory
# Processing Record 11 of Set 4 | hamilton
# Processing Record 12 of Set 4 | novogrudok
# Processing Record 13 of Set 4 | kerikeri
# Processing Record 14 of Set 4 | san patricio
# Processing Record 15 of Set 4 | ilulissat
# Processing Record 16 of Set 4 | talnakh
# Processing Record 17 of Set 4 | atamaria
# City not found. Skipping...
# Processing Record 18 of Set 4 | saanen
# Processing Record 19 of Set 4 | kurumkan
# Processing Record 20 of Set 4 | whitehorse
# Processing Record 21 of Set 4 | nizhneudinsk
# Processing Record 22 of Set 4 | shache
# Processing Record 23 of Set 4 | puerto ayora
# Processing Record 24 of Set 4 | cockburn town
# Processing Record 25 of Set 4 | emerald
# Processing Record 26 of Set 4 | battagram
# Processing Record 27 of Set 4 | san luis de la loma
# Processing Record 28 of Set 4 | darwin
# Processing Record 29 of Set 4 | longyearbyen
# Processing Record 30 of Set 4 | fauske
# Processing Record 31 of Set 4 | vilyuchinsk
# Processing Record 32 of Set 4 | arraial do cabo
# Processing Record 33 of Set 4 | enewetak
# Processing Record 34 of Set 4 | tucumcari
# Processing Record 35 of Set 4 | vadso
# Processing Record 36 of Set 4 | kerteminde
# Processing Record 37 of Set 4 | argo
# Processing Record 38 of Set 4 | lorengau
# Processing Record 39 of Set 4 | badger
# Processing Record 40 of Set 4 | sitka
# Processing Record 41 of Set 4 | barakani
# Processing Record 42 of Set 4 | tosontsengel
# Processing Record 43 of Set 4 | urangan
# Processing Record 44 of Set 4 | puerto baquerizo moreno
# Processing Record 45 of Set 4 | north platte
# Processing Record 46 of Set 4 | rugaji
# Processing Record 47 of Set 4 | phalodi
# Processing Record 48 of Set 4 | fale old settlement
# Processing Record 49 of Set 4 | kourou
# Processing Record 0 of Set 5 | waddan
# Processing Record 1 of Set 5 | gangtok
# Processing Record 2 of Set 5 | ouellah
# City not found. Skipping...
# Processing Record 3 of Set 5 | aleg
# Processing Record 4 of Set 5 | oriximina
# Processing Record 5 of Set 5 | vilyuysk
# Processing Record 6 of Set 5 | nar'yan-mar
# Processing Record 7 of Set 5 | sitia
# Processing Record 8 of Set 5 | hermanus
# Processing Record 9 of Set 5 | lompoc
# Processing Record 10 of Set 5 | gabu
# Processing Record 11 of Set 5 | touros
# Processing Record 12 of Set 5 | luderitz
# Processing Record 13 of Set 5 | broken hill
# Processing Record 14 of Set 5 | rakops
# Processing Record 15 of Set 5 | callao
# Processing Record 16 of Set 5 | fruita
# Processing Record 17 of Set 5 | tranovaho
# City not found. Skipping...
# Processing Record 18 of Set 5 | constitucion
# Processing Record 19 of Set 5 | pauini
# Processing Record 20 of Set 5 | santanyi
# Processing Record 21 of Set 5 | xiaoshan
# Processing Record 22 of Set 5 | oranjemund
# Processing Record 23 of Set 5 | shagonar
# Processing Record 24 of Set 5 | nizhniy odes
# Processing Record 25 of Set 5 | galliano
# Processing Record 26 of Set 5 | ust-nera
# Processing Record 27 of Set 5 | luganville
# Processing Record 28 of Set 5 | uturoa
# Processing Record 29 of Set 5 | murun-kuren
# Processing Record 30 of Set 5 | blackburn south
# Processing Record 31 of Set 5 | nyurba
# Processing Record 32 of Set 5 | belorechensk
# Processing Record 33 of Set 5 | krasnyye baki
# Processing Record 34 of Set 5 | mwinilunga
# Processing Record 35 of Set 5 | binhe
# Processing Record 36 of Set 5 | ust'-ordynskiy
# Processing Record 37 of Set 5 | vorgashor
# Processing Record 38 of Set 5 | guerrero negro
# Processing Record 39 of Set 5 | pontes e lacerda
# Processing Record 40 of Set 5 | sao jose da coroa grande
# Processing Record 41 of Set 5 | huarmey
# Processing Record 42 of Set 5 | ancud
# Processing Record 43 of Set 5 | alexandria
# Processing Record 44 of Set 5 | tosno
# Processing Record 45 of Set 5 | amancio
# City not found. Skipping...
# Processing Record 46 of Set 5 | mount pearl
# Processing Record 47 of Set 5 | caruthersville
# Processing Record 48 of Set 5 | khorramabad
# Processing Record 49 of Set 5 | laojunmiao
# Processing Record 0 of Set 6 | comodoro rivadavia
# Processing Record 1 of Set 6 | kodiak
# Processing Record 2 of Set 6 | ryotsu-minato
# Processing Record 3 of Set 6 | ceeldheer
# Processing Record 4 of Set 6 | port lincoln
# Processing Record 5 of Set 6 | tevriz
# Processing Record 6 of Set 6 | medvezh'yegorsk
# Processing Record 7 of Set 6 | rusape
# Processing Record 8 of Set 6 | hammerfest
# Processing Record 9 of Set 6 | mbaiki
# Processing Record 10 of Set 6 | nampula
# Processing Record 11 of Set 6 | leer
# Processing Record 12 of Set 6 | capdepera
# Processing Record 13 of Set 6 | punta arenas
# Processing Record 14 of Set 6 | thompson
# Processing Record 15 of Set 6 | kenai
# Processing Record 16 of Set 6 | paracuru
# Processing Record 17 of Set 6 | quixeramobim
# Processing Record 18 of Set 6 | kayangel
# Processing Record 19 of Set 6 | bonthe
# Processing Record 20 of Set 6 | tomatlan
# Processing Record 21 of Set 6 | manokwari
# Processing Record 22 of Set 6 | pamandzi
# Processing Record 23 of Set 6 | ulety
# Processing Record 24 of Set 6 | katsuren-haebaru
# Processing Record 25 of Set 6 | pula
# Processing Record 26 of Set 6 | staroleushkovskaya
# Processing Record 27 of Set 6 | vydrino
# Processing Record 28 of Set 6 | howard springs
# Processing Record 29 of Set 6 | san antonio de pale
# Processing Record 30 of Set 6 | lerwick
# Processing Record 31 of Set 6 | antofagasta
# Processing Record 32 of Set 6 | la ronge
# Processing Record 33 of Set 6 | san jose del guaviare
# Processing Record 34 of Set 6 | colonia
# Processing Record 35 of Set 6 | chililabombwe
# Processing Record 36 of Set 6 | kazalinsk
# City not found. Skipping...
# Processing Record 37 of Set 6 | tezu
# Processing Record 38 of Set 6 | ugoofaaru
# Processing Record 39 of Set 6 | egilsstadir
# Processing Record 40 of Set 6 | carutapera
# Processing Record 41 of Set 6 | cole harbour
# Processing Record 42 of Set 6 | pimentel
# Processing Record 43 of Set 6 | minab
# Processing Record 44 of Set 6 | polyarnyy
# Processing Record 45 of Set 6 | ola
# Processing Record 46 of Set 6 | prado
# Processing Record 47 of Set 6 | sinazongwe
# Processing Record 48 of Set 6 | yaren
# Processing Record 49 of Set 6 | tual
# Processing Record 0 of Set 7 | grimstad
# Processing Record 1 of Set 7 | manadhoo
# Processing Record 2 of Set 7 | saldanha
# Processing Record 3 of Set 7 | tres palos
# Processing Record 4 of Set 7 | bindura
# Processing Record 5 of Set 7 | cargados carajos
# City not found. Skipping...
# Processing Record 6 of Set 7 | kishtwar
# Processing Record 7 of Set 7 | vanimo
# Processing Record 8 of Set 7 | yanbu
# Processing Record 9 of Set 7 | kharan
# Processing Record 10 of Set 7 | miyanoura
# City not found. Skipping...
# Processing Record 11 of Set 7 | benalla
# Processing Record 12 of Set 7 | ponta delgada
# Processing Record 13 of Set 7 | peace river
# Processing Record 14 of Set 7 | magong
# Processing Record 15 of Set 7 | mejit
# Processing Record 16 of Set 7 | sechura
# Processing Record 17 of Set 7 | baotou
# Processing Record 18 of Set 7 | lebu
# Processing Record 19 of Set 7 | simanggang
# Processing Record 20 of Set 7 | saint-pierre
# Processing Record 21 of Set 7 | tura
# Processing Record 22 of Set 7 | basotu
# Processing Record 23 of Set 7 | strathmore
# Processing Record 24 of Set 7 | whitecourt
# Processing Record 25 of Set 7 | ca mau
# Processing Record 26 of Set 7 | kyren
# Processing Record 27 of Set 7 | devinuwara
# City not found. Skipping...
# Processing Record 28 of Set 7 | jaboticabal
# Processing Record 29 of Set 7 | naantali
# Processing Record 30 of Set 7 | gumdag
# Processing Record 31 of Set 7 | tyup
# Processing Record 32 of Set 7 | tenno
# Processing Record 33 of Set 7 | severo-yeniseyskiy
# Processing Record 34 of Set 7 | gonzaga
# Processing Record 35 of Set 7 | bac lieu
# Processing Record 36 of Set 7 | constantia
# Processing Record 37 of Set 7 | vesele
# Processing Record 38 of Set 7 | sinabang
# Processing Record 39 of Set 7 | nadi
# Processing Record 40 of Set 7 | chadan
# Processing Record 41 of Set 7 | ennis
# Processing Record 42 of Set 7 | kingston
# Processing Record 43 of Set 7 | kizhinga
# Processing Record 44 of Set 7 | happy valley-goose bay
# Processing Record 45 of Set 7 | chernyshevskiy
# Processing Record 46 of Set 7 | palmer
# Processing Record 47 of Set 7 | plastun
# Processing Record 48 of Set 7 | qaqortoq
# Processing Record 49 of Set 7 | balta
# Processing Record 0 of Set 8 | kavaratti
# Processing Record 1 of Set 8 | san pedro pochutla
# Processing Record 2 of Set 8 | kudahuvadhoo
# Processing Record 3 of Set 8 | acarau
# Processing Record 4 of Set 8 | 'ohonua
# City not found. Skipping...
# Processing Record 5 of Set 8 | zheleznogorsk
# Processing Record 6 of Set 8 | dakhla
# Processing Record 7 of Set 8 | nikolayevsk-on-amure
# Processing Record 8 of Set 8 | awjilah
# Processing Record 9 of Set 8 | vila franca do campo
# Processing Record 10 of Set 8 | trincomalee
# Processing Record 11 of Set 8 | bealanana
# Processing Record 12 of Set 8 | guatire
# Processing Record 13 of Set 8 | thai nguyen
# Processing Record 14 of Set 8 | cabo san lucas
# Processing Record 15 of Set 8 | al khums
# Processing Record 16 of Set 8 | hinton
# Processing Record 17 of Set 8 | jua dos vieiras
# City not found. Skipping...
# Processing Record 18 of Set 8 | machico
# Processing Record 19 of Set 8 | loushanguan
# Processing Record 20 of Set 8 | matlang
# Processing Record 21 of Set 8 | cururupu
# Processing Record 22 of Set 8 | villa gesell
# Processing Record 23 of Set 8 | neiafu
# Processing Record 24 of Set 8 | port augusta
# Processing Record 25 of Set 8 | iwon-up
# Processing Record 26 of Set 8 | nemuro
# Processing Record 27 of Set 8 | pasuquin
# Processing Record 28 of Set 8 | paramonga
# Processing Record 29 of Set 8 | nova sintra
# Processing Record 30 of Set 8 | nuku'alofa
# Processing Record 31 of Set 8 | bridgewater
# Processing Record 32 of Set 8 | miranda
# Processing Record 33 of Set 8 | santa maria
# Processing Record 34 of Set 8 | tralee
# Processing Record 35 of Set 8 | barmer
# Processing Record 36 of Set 8 | tremonton
# Processing Record 37 of Set 8 | camayenne
# Processing Record 38 of Set 8 | mercedes
# Processing Record 39 of Set 8 | meulaboh
# Processing Record 40 of Set 8 | mahibadhoo
# Processing Record 41 of Set 8 | nuuk
# Processing Record 42 of Set 8 | pukchil-lodongjagu
# Processing Record 43 of Set 8 | mao
# Processing Record 44 of Set 8 | ulsteinvik
# Processing Record 45 of Set 8 | aydin
# Processing Record 46 of Set 8 | porto novo
# Processing Record 47 of Set 8 | petropavlovsk-kamchatsky
# Processing Record 48 of Set 8 | wanning
# Processing Record 49 of Set 8 | chibougamau
# Processing Record 0 of Set 9 | rio preto da eva
# Processing Record 1 of Set 9 | chakari
# Processing Record 2 of Set 9 | gadzhiyevo
# Processing Record 3 of Set 9 | daigo
# Processing Record 4 of Set 9 | port alfred
# Processing Record 5 of Set 9 | westport
# Processing Record 6 of Set 9 | pacific grove
# Processing Record 7 of Set 9 | kembe
# Processing Record 8 of Set 9 | maragogi
# Processing Record 9 of Set 9 | makokou
# Processing Record 10 of Set 9 | as sulayyil
# Processing Record 11 of Set 9 | villanueva
# Processing Record 12 of Set 9 | jinxiang
# Processing Record 13 of Set 9 | ridder
# Processing Record 14 of Set 9 | machachi
# Processing Record 15 of Set 9 | warnsveld
# Processing Record 16 of Set 9 | iquique
# Processing Record 17 of Set 9 | port blair
# Processing Record 18 of Set 9 | impfondo
# Processing Record 19 of Set 9 | alotau
# City not found. Skipping...
# Processing Record 20 of Set 9 | saint-philippe
# Processing Record 21 of Set 9 | gafsa
# Processing Record 22 of Set 9 | abatskoye
# Processing Record 23 of Set 9 | fort mcmurray
# Processing Record 24 of Set 9 | yermentau
# Processing Record 25 of Set 9 | khanty-mansiysk
# Processing Record 26 of Set 9 | tabou
# Processing Record 27 of Set 9 | isla mujeres
# Processing Record 28 of Set 9 | arinos
# Processing Record 29 of Set 9 | shingu
# Processing Record 30 of Set 9 | dongola
# Processing Record 31 of Set 9 | razdol'noye
# Processing Record 32 of Set 9 | khorugh
# Processing Record 33 of Set 9 | whakatane
# Processing Record 34 of Set 9 | dingzhou
# Processing Record 35 of Set 9 | baskale
# Processing Record 36 of Set 9 | ciudad lazaro cardenas
# Processing Record 37 of Set 9 | senador jose porfirio
# Processing Record 38 of Set 9 | al hazm
# Processing Record 39 of Set 9 | nishinoomote
# Processing Record 40 of Set 9 | albu kamal
# Processing Record 41 of Set 9 | kirakira
# Processing Record 42 of Set 9 | barysh
# Processing Record 43 of Set 9 | mermoz boabab
# Processing Record 44 of Set 9 | usogorsk
# Processing Record 45 of Set 9 | lloydminster
# Processing Record 46 of Set 9 | veraval
# Processing Record 47 of Set 9 | sokoni
# Processing Record 48 of Set 9 | dadonghai
# City not found. Skipping...
# Processing Record 49 of Set 9 | garh maharaja
# Processing Record 0 of Set 10 | pembroke
# Processing Record 1 of Set 10 | bubaque
# Processing Record 2 of Set 10 | breckenridge
# Processing Record 3 of Set 10 | al 'alamayn
# City not found. Skipping...
# Processing Record 4 of Set 10 | pisco
# Processing Record 5 of Set 10 | tanjung selor
# City not found. Skipping...
# Processing Record 6 of Set 10 | guarapari
# Processing Record 7 of Set 10 | alamar
# Processing Record 8 of Set 10 | greymouth
# Processing Record 9 of Set 10 | conception bay south
# Processing Record 10 of Set 10 | saint john
# Processing Record 11 of Set 10 | walvis bay
# Processing Record 12 of Set 10 | eureka
# Processing Record 13 of Set 10 | beni mellal
# Processing Record 14 of Set 10 | gwanda
# Processing Record 15 of Set 10 | bandarbeyla
# Processing Record 16 of Set 10 | oelwein
# Processing Record 17 of Set 10 | jiangzi
# Processing Record 18 of Set 10 | sao vicente
# Processing Record 19 of Set 10 | qurayyat
# Processing Record 20 of Set 10 | ballesteros
# Processing Record 21 of Set 10 | buka
# Processing Record 22 of Set 10 | north elba
# Processing Record 23 of Set 10 | toliara
# Processing Record 24 of Set 10 | mitu
# Processing Record 25 of Set 10 | altai
# Processing Record 26 of Set 10 | tajiri
# Processing Record 27 of Set 10 | kuanda
# Processing Record 28 of Set 10 | coronel suarez
# Processing Record 29 of Set 10 | isangel
# Processing Record 30 of Set 10 | conneaut
# Processing Record 31 of Set 10 | eydhafushi
# Processing Record 32 of Set 10 | tursunzoda
# Processing Record 33 of Set 10 | balashikha
# Processing Record 34 of Set 10 | mountain home
# Processing Record 35 of Set 10 | cozumel
# Processing Record 36 of Set 10 | zabol
# Processing Record 37 of Set 10 | koshki
# Processing Record 38 of Set 10 | muscat
# Processing Record 39 of Set 10 | midar
# Processing Record 40 of Set 10 | serenje
# Processing Record 41 of Set 10 | kisangani
# Processing Record 42 of Set 10 | karratha
# Processing Record 43 of Set 10 | umarkot
# Processing Record 44 of Set 10 | smara
# Processing Record 45 of Set 10 | yelovo
# Processing Record 46 of Set 10 | bor
# Processing Record 47 of Set 10 | hihifo
# City not found. Skipping...
# Processing Record 48 of Set 10 | portland
# Processing Record 49 of Set 10 | coahuayana de hidalgo
# Processing Record 0 of Set 11 | nguigmi
# Processing Record 1 of Set 11 | livingstone
# Processing Record 2 of Set 11 | east london
# Processing Record 3 of Set 11 | undurkhaan
# Processing Record 4 of Set 11 | gereshk
# Processing Record 5 of Set 11 | hirado
# Processing Record 6 of Set 11 | zaragoza
# Processing Record 7 of Set 11 | crane
# Processing Record 8 of Set 11 | torrevieja
# Processing Record 9 of Set 11 | matoury
# Processing Record 10 of Set 11 | santa rosa
# Processing Record 11 of Set 11 | izhmorskiy
# Processing Record 12 of Set 11 | afif
# Processing Record 13 of Set 11 | boende
# Processing Record 14 of Set 11 | rio grande
# Processing Record 15 of Set 11 | palikir - national government center
# Processing Record 16 of Set 11 | huaiyuan chengguanzhen
# Processing Record 17 of Set 11 | fort bragg
# Processing Record 18 of Set 11 | khunti
# Processing Record 19 of Set 11 | aq qayeh
# City not found. Skipping...
# Processing Record 20 of Set 11 | grants pass
# Processing Record 21 of Set 11 | mount isa
# Processing Record 22 of Set 11 | zhanaozen
# Processing Record 23 of Set 11 | aragarcas
# Processing Record 24 of Set 11 | mont-tremblant
# Processing Record 25 of Set 11 | valparaiso
# Processing Record 26 of Set 11 | ouesso
# Processing Record 27 of Set 11 | selkirk
# Processing Record 28 of Set 11 | ves'yegonsk
# Processing Record 29 of Set 11 | ma'an
# Processing Record 30 of Set 11 | kilju
# Processing Record 31 of Set 11 | lakatoro
# Processing Record 32 of Set 11 | shortandy
# Processing Record 33 of Set 11 | labrador city
# Processing Record 34 of Set 11 | el porvenir
# Processing Record 35 of Set 11 | mugia
# Processing Record 36 of Set 11 | hamada
# Processing Record 37 of Set 11 | biloela
# Processing Record 38 of Set 11 | 'ain el turk
# Processing Record 39 of Set 11 | beau vallon
# Processing Record 40 of Set 11 | zaysan
# Processing Record 41 of Set 11 | quelimane
# Processing Record 42 of Set 11 | cannonvale
# Processing Record 43 of Set 11 | herzliya pituah
# City not found. Skipping...
# Processing Record 44 of Set 11 | ambovombe
# Processing Record 45 of Set 11 | tsiolkovskiy
# City not found. Skipping...
# Processing Record 46 of Set 11 | kulia village
# City not found. Skipping...
# Processing Record 47 of Set 11 | okhotsk
# Processing Record 48 of Set 11 | ahar
# Processing Record 49 of Set 11 | newark
# Processing Record 0 of Set 12 | kailua-kona
# Processing Record 1 of Set 12 | la palma
# Processing Record 2 of Set 12 | sarupathar
# Processing Record 3 of Set 12 | mirnyy
# Processing Record 4 of Set 12 | monrovia
# Processing Record 5 of Set 12 | feodosiya
# Processing Record 6 of Set 12 | camabatela
# Processing Record 7 of Set 12 | nelsonville
# Processing Record 8 of Set 12 | kidal
# Processing Record 9 of Set 12 | takoradi
# Processing Record 10 of Set 12 | concordia
# Processing Record 11 of Set 12 | bam
# Processing Record 12 of Set 12 | panchkula
# Processing Record 13 of Set 12 | wanxian
# Processing Record 14 of Set 12 | novo aripuana
# Processing Record 15 of Set 12 | taroa
# Processing Record 16 of Set 12 | phuthaditjhaba
# Processing Record 17 of Set 12 | noshiro
# Processing Record 18 of Set 12 | kokpekty
# Processing Record 19 of Set 12 | kone
# Processing Record 20 of Set 12 | thinadhoo
# Processing Record 21 of Set 12 | abbiategrasso
# Processing Record 22 of Set 12 | anicuns
# Processing Record 23 of Set 12 | taoudenni
# Processing Record 24 of Set 12 | salekhard
# Processing Record 25 of Set 12 | mazatlan
# Processing Record 26 of Set 12 | fort st. john
# Processing Record 27 of Set 12 | ta`u
# Processing Record 28 of Set 12 | aleksandrovsk-sakhalinskiy
# Processing Record 29 of Set 12 | el granada
# Processing Record 30 of Set 12 | fernandopolis
# Processing Record 31 of Set 12 | ujae
# Processing Record 32 of Set 12 | broome
# Processing Record 33 of Set 12 | geraldton
# Processing Record 34 of Set 12 | tarko-sale
# Processing Record 35 of Set 12 | island harbour
# Processing Record 36 of Set 12 | argostolion
# Processing Record 37 of Set 12 | alesund
# Processing Record 38 of Set 12 | berbera
# Processing Record 39 of Set 12 | tome acu
# Processing Record 40 of Set 12 | kingscliff
# Processing Record 41 of Set 12 | faya-largeau
# Processing Record 42 of Set 12 | barreirinha
# -----------------------------
# Data Retrieval Complete
# -----------------------------

# %%
city_data
# Out:
# [{'City': 'afaahiti',
#   'Lat': -17.75,
#   'Lng': -149.2833,
#   'Max Temp': 29.93,
#   'Humidity': 82,
#   'Cloudiness': 100,
#   'Wind Speed': 8.1,
#   'Country': 'PF',
#   'Date': 1712783702},
#  {'City': 'papatowai',
#   'Lat': -46.5619,
#   'Lng': 169.4708,
#   'Max Temp': 12.01,
#   'Humidity': 100,
#   'Cloudiness': 100,
#   'Wind Speed': 2.62,
#   'Country': 'NZ',
#   'Date': 1712783702},
#  {'City': 'aasiaat',
#   'Lat': 68.7098,
#   'Lng': -52.8699,
#   'Max Temp': -7.19,
#   'Humidity': 78,
#   'Cloudiness': 100,
#   'Wind Speed': 2.59,
#   'Country': 'GL',
#   'Date': 1712783703},
#  {'City': 'lhasa',
#   'Lat': 29.65,
#   'Lng': 91.1,
#   'Max Temp': 2.13,
#   'Humidity': 68,
#   'Cloudiness': 86,
#   'Wind Speed': 1.18,
#   'Country': 'CN',
#   'Date': 1712783703},
#  {'City': 'port elizabeth',
#   'Lat': -33.918,
#   'Lng': 25.5701,
#   'Max Temp': 15.17,
#   'Humidity': 85,
#   'Cloudiness': 100,
#   'Wind Speed': 1.34,
#   'Country': 'ZA',
#   'Date': 1712783704},
#  {'City': 'kalashnikovo',
#   'Lat': 57.2824,
#   'Lng': 35.2262,
#   'Max Temp': 14.33,
#   'Humidity': 93,
#   'Cloudiness': 100,
#   'Wind Speed': 3.45,
#   'Country': 'RU',
#   'Date': 1712783704},
#  {'City': 'blackmans bay',
#   'Lat': -43.0167,
#   'Lng': 147.3167,
#   'Max Temp': 8.07,
#   'Humidity': 91,
#   'Cloudiness': 69,
#   'Wind Speed': 0.89,
#   'Country': 'AU',
#   'Date': 1712783704},
#  {'City': 'anadyr',
#   'Lat': 64.75,
#   'Lng': 177.4833,
#   'Max Temp': -8.72,
#   'Humidity': 85,
#   'Cloudiness': 40,
#   'Wind Speed': 5.81,
#   'Country': 'RU',
#   'Date': 1712783704},
#  {'City': 'jamestown',
#   'Lat': 42.097,
#   'Lng': -79.2353,
#   'Max Temp': 16.77,
#   'Humidity': 67,
#   'Cloudiness': 100,
#   'Wind Speed': 1.54,
#   'Country': 'US',
#   'Date': 1712783539},
#  {'City': 'kamaishi',
#   'Lat': 39.2667,
#   'Lng': 141.8833,
#   'Max Temp': 5.78,
#   'Humidity': 78,
#   'Cloudiness': 85,
#   'Wind Speed': 3.02,
#   'Country': 'JP',
#   'Date': 1712783705},
#  {'City': 'ushuaia',
#   'Lat': -54.8,
#   'Lng': -68.3,
#   'Max Temp': 6.81,
#   'Humidity': 76,
#   'Cloudiness': 20,
#   'Wind Speed': 14.92,
#   'Country': 'AR',
#   'Date': 1712783651},
#  {'City': 'totness',
#   'Lat': 5.8833,
#   'Lng': -56.3167,
#   'Max Temp': 28.05,
#   'Humidity': 76,
#   'Cloudiness': 98,
#   'Wind Speed': 4.61,
#   'Country': 'SR',
#   'Date': 1712783531},
#  {'City': 'waitangi',
#   'Lat': -43.9535,
#   'Lng': -176.5597,
#   'Max Temp': 16.57,
#   'Humidity': 92,
#   'Cloudiness': 97,
#   'Wind Speed': 4.47,
#   'Country': 'NZ',
#   'Date': 1712783705},
#  {'City': 'ondjiva',
#   'Lat': -17.0667,
#   'Lng': 15.7333,
#   'Max Temp': 24.55,
#   'Humidity': 33,
#   'Cloudiness': 5,
#   'Wind Speed': 2.78,
#   'Country': 'AO',
#   'Date': 1712783705},
#  {'City': 'la passe',
#   'Lat': 45.5549,
#   'Lng': -0.8967,
#   'Max Temp': 12.23,
#   'Humidity': 82,
#   'Cloudiness': 95,
#   'Wind Speed': 1.87,
#   'Country': 'FR',
#   'Date': 1712783540},
#  {'City': 'remire-montjoly',
#   'Lat': 4.9167,
#   'Lng': -52.2667,
#   'Max Temp': 29.02,
#   'Humidity': 84,
#   'Cloudiness': 75,
#   'Wind Speed': 4.63,
#   'Country': 'GF',
#   'Date': 1712783705},
#  {'City': 'olinda',
#   'Lat': -8.0089,
#   'Lng': -34.8553,
#   'Max Temp': 27.85,
#   'Humidity': 83,
#   'Cloudiness': 20,
#   'Wind Speed': 1.03,
#   'Country': 'BR',
#   'Date': 1712783706},
#  {'City': 'suva',
#   'Lat': -18.1416,
#   'Lng': 178.4415,
#   'Max Temp': 28.71,
#   'Humidity': 79,
#   'Cloudiness': 75,
#   'Wind Speed': 5.14,
#   'Country': 'FJ',
#   'Date': 1712783509},
#  {'City': 'adamstown',
#   'Lat': -25.066,
#   'Lng': -130.1015,
#   'Max Temp': 22.85,
#   'Humidity': 84,
#   'Cloudiness': 100,
#   'Wind Speed': 2.8,
#   'Country': 'PN',
#   'Date': 1712783706},
#  {'City': 'invercargill',
#   'Lat': -46.4,
#   'Lng': 168.35,
#   'Max Temp': 10.57,
#   'Humidity': 98,
#   'Cloudiness': 100,
#   'Wind Speed': 5.36,
#   'Country': 'NZ',
#   'Date': 1712783706},
#  {'City': 'casablanca',
#   'Lat': 33.5928,
#   'Lng': -7.6192,
#   'Max Temp': 20.18,
#   'Humidity': 60,
#   'Cloudiness': 12,
#   'Wind Speed': 2.68,
#   'Country': 'MA',
#   'Date': 1712783568},
#  {'City': 'bethel',
#   'Lat': 41.3712,
#   'Lng': -73.414,
#   'Max Temp': 19.64,
#   'Humidity': 65,
#   'Cloudiness': 20,
#   'Wind Speed': 3.6,
#   'Country': 'US',
#   'Date': 1712783526},
#  {'City': 'margaret river',
#   'Lat': -33.95,
#   'Lng': 115.0667,
#   'Max Temp': 13.48,
#   'Humidity': 76,
#   'Cloudiness': 7,
#   'Wind Speed': 5.56,
#   'Country': 'AU',
#   'Date': 1712783706},
#  {'City': 'port-aux-francais',
#   'Lat': -49.35,
#   'Lng': 70.2167,
#   'Max Temp': 7.69,
#   'Humidity': 98,
#   'Cloudiness': 100,
#   'Wind Speed': 3.3,
#   'Country': 'TF',
#   'Date': 1712783706},
#  {'City': 'tolanaro',
#   'Lat': -25.0319,
#   'Lng': 46.9987,
#   'Max Temp': 24.02,
#   'Humidity': 91,
#   'Cloudiness': 96,
#   'Wind Speed': 1.84,
#   'Country': 'MG',
#   'Date': 1712783707},
#  {'City': 'newman',
#   'Lat': 37.3138,
#   'Lng': -121.0208,
#   'Max Temp': 26.25,
#   'Humidity': 50,
#   'Cloudiness': 89,
#   'Wind Speed': 1.34,
#   'Country': 'US',
#   'Date': 1712783707},
#  {'City': 'klyuchi',
#   'Lat': 52.2667,
#   'Lng': 79.1667,
#   'Max Temp': 3.56,
#   'Humidity': 88,
#   'Cloudiness': 100,
#   'Wind Speed': 0.22,
#   'Country': 'RU',
#   'Date': 1712783707},
#  {'City': 'boa vista',
#   'Lat': 2.8197,
#   'Lng': -60.6733,
#   'Max Temp': 34.99,
#   'Humidity': 36,
#   'Cloudiness': 20,
#   'Wind Speed': 5.14,
#   'Country': 'BR',
#   'Date': 1712783548},
#  {'City': 'minas de marcona',
#   'Lat': -15.2119,
#   'Lng': -75.1103,
#   'Max Temp': 20.23,
#   'Humidity': 68,
#   'Cloudiness': 90,
#   'Wind Speed': 6.46,
#   'Country': 'PE',
#   'Date': 1712783707},
#  {'City': 'grytviken',
#   'Lat': -54.2811,
#   'Lng': -36.5092,
#   'Max Temp': 1.42,
#   'Humidity': 85,
#   'Cloudiness': 12,
#   'Wind Speed': 5.18,
#   'Country': 'GS',
#   'Date': 1712783708},
#  {'City': 'trosa',
#   'Lat': 58.8962,
#   'Lng': 17.5481,
#   'Max Temp': 7.98,
#   'Humidity': 67,
#   'Cloudiness': 6,
#   'Wind Speed': 7.57,
#   'Country': 'SE',
#   'Date': 1712783708},
#  {'City': 'queenstown',
#   'Lat': -31.8976,
#   'Lng': 26.8753,
#   'Max Temp': 11.28,
#   'Humidity': 81,
#   'Cloudiness': 99,
#   'Wind Speed': 1.99,
#   'Country': 'ZA',
#   'Date': 1712783583},
#  {'City': 'bredasdorp',
#   'Lat': -34.5322,
#   'Lng': 20.0403,
#   'Max Temp': 15.18,
#   'Humidity': 68,
#   'Cloudiness': 45,
#   'Wind Speed': 6.08,
#   'Country': 'ZA',
#   'Date': 1712783708},
#  {'City': 'bafq',
#   'Lat': 31.6128,
#   'Lng': 55.4107,
#   'Max Temp': 25.52,
#   'Humidity': 22,
#   'Cloudiness': 19,
#   'Wind Speed': 7.65,
#   'Country': 'IR',
#   'Date': 1712783708},
#  {'City': 'iskateley',
#   'Lat': 67.6803,
#   'Lng': 53.1512,
#   'Max Temp': -13.88,
#   'Humidity': 96,
#   'Cloudiness': 100,
#   'Wind Speed': 2.68,
#   'Country': 'RU',
#   'Date': 1712783708},
#  {'City': 'kankaanpaa',
#   'Lat': 61.8,
#   'Lng': 22.4167,
#   'Max Temp': 4.42,
#   'Humidity': 95,
#   'Cloudiness': 100,
#   'Wind Speed': 5.05,
#   'Country': 'FI',
#   'Date': 1712783708},
#  {'City': 'benjamin hill',
#   'Lat': 30.1667,
#   'Lng': -111.1,
#   'Max Temp': 26.91,
#   'Humidity': 10,
#   'Cloudiness': 0,
#   'Wind Speed': 4.26,
#   'Country': 'MX',
#   'Date': 1712783708},
#  {'City': 'sola',
#   'Lat': -13.8833,
#   'Lng': 167.55,
#   'Max Temp': 27.42,
#   'Humidity': 75,
#   'Cloudiness': 96,
#   'Wind Speed': 1.18,
#   'Country': 'VU',
#   'Date': 1712783709},
#  {'City': 'salinera colan',
#   'Lat': -5.0333,
#   'Lng': -81.0667,
#   'Max Temp': 27.52,
#   'Humidity': 62,
#   'Cloudiness': 50,
#   'Wind Speed': 7.3,
#   'Country': 'PE',
#   'Date': 1712783709},
#  {'City': 'aykhal',
#   'Lat': 66,
#   'Lng': 111.5,
#   'Max Temp': -26.75,
#   'Humidity': 98,
#   'Cloudiness': 57,
#   'Wind Speed': 9.19,
#   'Country': 'RU',
#   'Date': 1712783709},
#  {'City': 'puerto natales',
#   'Lat': -51.7236,
#   'Lng': -72.4875,
#   'Max Temp': 9.25,
#   'Humidity': 61,
#   'Cloudiness': 0,
#   'Wind Speed': 7.2,
#   'Country': 'CL',
#   'Date': 1712783709},
#  {'City': 'frutal',
#   'Lat': -20.0247,
#   'Lng': -48.9406,
#   'Max Temp': 26.65,
#   'Humidity': 66,
#   'Cloudiness': 50,
#   'Wind Speed': 1.37,
#   'Country': 'BR',
#   'Date': 1712783709},
#  {'City': 'ragana',
#   'Lat': 57.1803,
#   'Lng': 24.7144,
#   'Max Temp': 8.53,
#   'Humidity': 82,
#   'Cloudiness': 100,
#   'Wind Speed': 5.76,
#   'Country': 'LV',
#   'Date': 1712783709},
#  {'City': 'dapa',
#   'Lat': 9.7594,
#   'Lng': 126.0531,
#   'Max Temp': 25.59,
#   'Humidity': 82,
#   'Cloudiness': 88,
#   'Wind Speed': 0.77,
#   'Country': 'PH',
#   'Date': 1712783710},
#  {'City': 'codrington',
#   'Lat': -38.2667,
#   'Lng': 141.9667,
#   'Max Temp': 14.09,
#   'Humidity': 72,
#   'Cloudiness': 82,
#   'Wind Speed': 5.25,
#   'Country': 'AU',
#   'Date': 1712783710},
#  {'City': 'chonchi',
#   'Lat': -42.6128,
#   'Lng': -73.8092,
#   'Max Temp': 15.56,
#   'Humidity': 55,
#   'Cloudiness': 0,
#   'Wind Speed': 1.2,
#   'Country': 'CL',
#   'Date': 1712783710},
#  {'City': 'yeppoon',
#   'Lat': -23.1333,
#   'Lng': 150.7333,
#   'Max Temp': 12.88,
#   'Humidity': 61,
#   'Cloudiness': 0,
#   'Wind Speed': 2.38,
#   'Country': 'AU',
#   'Date': 1712783710},
#  {'City': 'enumclaw',
#   'Lat': 47.2043,
#   'Lng': -121.9915,
#   'Max Temp': 16.58,
#   'Humidity': 56,
#   'Cloudiness': 73,
#   'Wind Speed': 1.79,
#   'Country': 'US',
#   'Date': 1712783710},
#  {'City': 'alofi',
#   'Lat': -19.0595,
#   'Lng': -169.9187,
#   'Max Temp': 26.94,
#   'Humidity': 89,
#   'Cloudiness': 75,
#   'Wind Speed': 4.12,
#   'Country': 'NU',
#   'Date': 1712783710},
#  {'City': 'levuka',
#   'Lat': 50.1834,
#   'Lng': -105.4011,
#   'Max Temp': 9.88,
#   'Humidity': 33,
#   'Cloudiness': 100,
#   'Wind Speed': 9.4,
#   'Country': 'CA',
#   'Date': 1712783710},
#  {'City': 'tiksi',
#   'Lat': 71.6872,
#   'Lng': 128.8694,
#   'Max Temp': -16.46,
#   'Humidity': 97,
#   'Cloudiness': 100,
#   'Wind Speed': 4.5,
#   'Country': 'RU',
#   'Date': 1712783710},
#  {'City': 'charters towers',
#   'Lat': -20.1,
#   'Lng': 146.2667,
#   'Max Temp': 16.04,
#   'Humidity': 39,
#   'Cloudiness': 69,
#   'Wind Speed': 4.35,
#   'Country': 'AU',
#   'Date': 1712783711},
#  {'City': 'georgetown',
#   'Lat': 5.4112,
#   'Lng': 100.3354,
#   'Max Temp': 27.75,
#   'Humidity': 94,
#   'Cloudiness': 20,
#   'Wind Speed': 1.54,
#   'Country': 'MY',
#   'Date': 1712783543},
#  {'City': 'gulf breeze',
#   'Lat': 30.3571,
#   'Lng': -87.1639,
#   'Max Temp': 19.43,
#   'Humidity': 97,
#   'Cloudiness': 100,
#   'Wind Speed': 10.8,
#   'Country': 'US',
#   'Date': 1712783711},
#  {'City': 'mount gambier',
#   'Lat': -37.8333,
#   'Lng': 140.7667,
#   'Max Temp': 12.99,
#   'Humidity': 82,
#   'Cloudiness': 100,
#   'Wind Speed': 1.98,
#   'Country': 'AU',
#   'Date': 1712783711},
#  {'City': 'edinburgh of the seven seas',
#   'Lat': -37.0676,
#   'Lng': -12.3116,
#   'Max Temp': 17.84,
#   'Humidity': 81,
#   'Cloudiness': 73,
#   'Wind Speed': 2.75,
#   'Country': 'SH',
#   'Date': 1712783711},
#  {'City': 'winnemucca',
#   'Lat': 40.973,
#   'Lng': -117.7357,
#   'Max Temp': 19.03,
#   'Humidity': 26,
#   'Cloudiness': 0,
#   'Wind Speed': 2.19,
#   'Country': 'US',
#   'Date': 1712783711},
#  {'City': 'cosesti',
#   'Lat': 45.0667,
#   'Lng': 24.8667,
#   'Max Temp': 13.34,
#   'Humidity': 54,
#   'Cloudiness': 6,
#   'Wind Speed': 1.79,
#   'Country': 'RO',
#   'Date': 1712783711},
#  {'City': 'iqaluit',
#   'Lat': 63.7506,
#   'Lng': -68.5145,
#   'Max Temp': -0.17,
#   'Humidity': 88,
#   'Cloudiness': 37,
#   'Wind Speed': 2.68,
#   'Country': 'CA',
#   'Date': 1712783711},
#  {'City': 'lihue',
#   'Lat': 21.9789,
#   'Lng': -159.3672,
#   'Max Temp': 28.58,
#   'Humidity': 67,
#   'Cloudiness': 0,
#   'Wind Speed': 4.12,
#   'Country': 'US',
#   'Date': 1712783712},
#  {'City': 'loreto',
#   'Lat': 22.2667,
#   'Lng': -101.9667,
#   'Max Temp': 26.87,
#   'Humidity': 7,
#   'Cloudiness': 4,
#   'Wind Speed': 8.88,
#   'Country': 'MX',
#   'Date': 1712783712},
#  {'City': 'yellowknife',
#   'Lat': 62.456,
#   'Lng': -114.3525,
#   'Max Temp': 3.01,
#   'Humidity': 82,
#   'Cloudiness': 9,
#   'Wind Speed': 2.24,
#   'Country': 'CA',
#   'Date': 1712783712},
#  {'City': 'wailua homesteads',
#   'Lat': 22.0669,
#   'Lng': -159.378,
#   'Max Temp': 28.24,
#   'Humidity': 74,
#   'Cloudiness': 0,
#   'Wind Speed': 4.12,
#   'Country': 'US',
#   'Date': 1712783712},
#  {'City': 'antigonish',
#   'Lat': 45.6169,
#   'Lng': -61.9986,
#   'Max Temp': 6.75,
#   'Humidity': 57,
#   'Cloudiness': 0,
#   'Wind Speed': 2.82,
#   'Country': 'CA',
#   'Date': 1712783712},
#  {'City': "st. john's",
#   'Lat': 47.5649,
#   'Lng': -52.7093,
#   'Max Temp': 0.38,
#   'Humidity': 82,
#   'Cloudiness': 75,
#   'Wind Speed': 4.63,
#   'Country': 'CA',
#   'Date': 1712783644},
#  {'City': 'tazacorte',
#   'Lat': 28.629,
#   'Lng': -17.9293,
#   'Max Temp': 19.54,
#   'Humidity': 77,
#   'Cloudiness': 75,
#   'Wind Speed': 6.69,
#   'Country': 'ES',
#   'Date': 1712783712},
#  {'City': 'stanley',
#   'Lat': 54.868,
#   'Lng': -1.6985,
#   'Max Temp': 12.77,
#   'Humidity': 88,
#   'Cloudiness': 75,
#   'Wind Speed': 7.2,
#   'Country': 'GB',
#   'Date': 1712783656},
#  {'City': 'tilisarao',
#   'Lat': -32.7329,
#   'Lng': -65.2911,
#   'Max Temp': 10.21,
#   'Humidity': 81,
#   'Cloudiness': 100,
#   'Wind Speed': 5.17,
#   'Country': 'AR',
#   'Date': 1712783713},
#  {'City': 'sunne',
#   'Lat': 59.8376,
#   'Lng': 13.143,
#   'Max Temp': 7.23,
#   'Humidity': 70,
#   'Cloudiness': 11,
#   'Wind Speed': 5.52,
#   'Country': 'SE',
#   'Date': 1712783713},
#  {'City': 'izberbash',
#   'Lat': 42.5696,
#   'Lng': 47.8645,
#   'Max Temp': 9.03,
#   'Humidity': 82,
#   'Cloudiness': 100,
#   'Wind Speed': 2.08,
#   'Country': 'RU',
#   'Date': 1712783713},
#  {'City': 'hawaiian paradise park',
#   'Lat': 19.5933,
#   'Lng': -154.9731,
#   'Max Temp': 25.49,
#   'Humidity': 79,
#   'Cloudiness': 100,
#   'Wind Speed': 2.06,
#   'Country': 'US',
#   'Date': 1712783713},
#  {'City': 'bilibino',
#   'Lat': 68.0546,
#   'Lng': 166.4372,
#   'Max Temp': -17.91,
#   'Humidity': 95,
#   'Cloudiness': 80,
#   'Wind Speed': 0.87,
#   'Country': 'RU',
#   'Date': 1712783713},
#  {'City': 'susuman',
#   'Lat': 62.7833,
#   'Lng': 148.1667,
#   'Max Temp': -19.45,
#   'Humidity': 99,
#   'Cloudiness': 88,
#   'Wind Speed': 0.45,
#   'Country': 'RU',
#   'Date': 1712783713},
#  {'City': 'jawf al maqbabah',
#   'Lat': 13.8378,
#   'Lng': 45.8349,
#   'Max Temp': 24.38,
#   'Humidity': 71,
#   'Cloudiness': 4,
#   'Wind Speed': 0.45,
#   'Country': 'YE',
#   'Date': 1712783713},
#  {'City': 'tsagan aman',
#   'Lat': 47.5639,
#   'Lng': 46.7218,
#   'Max Temp': 16.22,
#   'Humidity': 47,
#   'Cloudiness': 0,
#   'Wind Speed': 1.87,
#   'Country': 'RU',
#   'Date': 1712783713},
#  {'City': 'kuta',
#   'Lat': -8.7233,
#   'Lng': 115.1723,
#   'Max Temp': 26.97,
#   'Humidity': 88,
#   'Cloudiness': 20,
#   'Wind Speed': 1.54,
#   'Country': 'ID',
#   'Date': 1712783714},
#  {'City': 'port mathurin',
#   'Lat': -19.6833,
#   'Lng': 63.4167,
#   'Max Temp': 26.63,
#   'Humidity': 78,
#   'Cloudiness': 32,
#   'Wind Speed': 5.6,
#   'Country': 'MU',
#   'Date': 1712783714},
#  {'City': 'olonkinbyen',
#   'Lat': 70.9221,
#   'Lng': -8.7187,
#   'Max Temp': -6.35,
#   'Humidity': 71,
#   'Cloudiness': 100,
#   'Wind Speed': 5.52,
#   'Country': 'SJ',
#   'Date': 1712783714},
#  {'City': 'ribeira grande',
#   'Lat': 38.5167,
#   'Lng': -28.7,
#   'Max Temp': 17.1,
#   'Humidity': 100,
#   'Cloudiness': 100,
#   'Wind Speed': 5.66,
#   'Country': 'PT',
#   'Date': 1712783714},
#  {'City': 'udachny',
#   'Lat': 66.4167,
#   'Lng': 112.4,
#   'Max Temp': -21.97,
#   'Humidity': 87,
#   'Cloudiness': 87,
#   'Wind Speed': 10.8,
#   'Country': 'RU',
#   'Date': 1712783714},
#  {'City': 'utrik',
#   'Lat': 11.2278,
#   'Lng': 169.8474,
#   'Max Temp': 26.59,
#   'Humidity': 77,
#   'Cloudiness': 100,
#   'Wind Speed': 9.99,
#   'Country': 'MH',
#   'Date': 1712783714},
#  {'City': 'amalapuram',
#   'Lat': 16.5833,
#   'Lng': 82.0167,
#   'Max Temp': 23.44,
#   'Humidity': 96,
#   'Cloudiness': 1,
#   'Wind Speed': 0.62,
#   'Country': 'IN',
#   'Date': 1712783714},
#  {'City': 'lata',
#   'Lat': 40.1629,
#   'Lng': -8.3327,
#   'Max Temp': 15.51,
#   'Humidity': 82,
#   'Cloudiness': 98,
#   'Wind Speed': 1.34,
#   'Country': 'PT',
#   'Date': 1712783715},
#  {'City': 'asekeyevo',
#   'Lat': 53.5742,
#   'Lng': 52.7972,
#   'Max Temp': 6.69,
#   'Humidity': 82,
#   'Cloudiness': 4,
#   'Wind Speed': 2.29,
#   'Country': 'RU',
#   'Date': 1712783715},
#  {'City': 'madzhalis',
#   'Lat': 42.1217,
#   'Lng': 47.8333,
#   'Max Temp': 11.88,
#   'Humidity': 91,
#   'Cloudiness': 100,
#   'Wind Speed': 1.68,
#   'Country': 'RU',
#   'Date': 1712783715},
#  {'City': 'atafu village',
#   'Lat': -8.5421,
#   'Lng': -172.5159,
#   'Max Temp': 29.9,
#   'Humidity': 76,
#   'Cloudiness': 68,
#   'Wind Speed': 4.93,
#   'Country': 'TK',
#   'Date': 1712783715},
#  {'City': 'de soto',
#   'Lat': 34.9248,
#   'Lng': -89.9904,
#   'Max Temp': 20.13,
#   'Humidity': 85,
#   'Cloudiness': 75,
#   'Wind Speed': 3.6,
#   'Country': 'US',
#   'Date': 1712783715},
#  {'City': 'lethem',
#   'Lat': 3.3803,
#   'Lng': -59.7968,
#   'Max Temp': 36.87,
#   'Humidity': 31,
#   'Cloudiness': 93,
#   'Wind Speed': 6.32,
#   'Country': 'GY',
#   'Date': 1712783715},
#  {'City': 'bardai',
#   'Lat': 11.65,
#   'Lng': 7.2333,
#   'Max Temp': 30.22,
#   'Humidity': 18,
#   'Cloudiness': 40,
#   'Wind Speed': 4.73,
#   'Country': 'NG',
#   'Date': 1712783715},
#  {'City': 'rongelap',
#   'Lat': 11.1635,
#   'Lng': 166.8941,
#   'Max Temp': 26.7,
#   'Humidity': 81,
#   'Cloudiness': 100,
#   'Wind Speed': 10.68,
#   'Country': 'MH',
#   'Date': 1712783715},
#  {'City': 'ludington',
#   'Lat': 43.9553,
#   'Lng': -86.4526,
#   'Max Temp': 19.34,
#   'Humidity': 31,
#   'Cloudiness': 0,
#   'Wind Speed': 5.14,
#   'Country': 'US',
#   'Date': 1712783716},
#  {'City': 'hadibu',
#   'Lat': 12.65,
#   'Lng': 54.0333,
#   'Max Temp': 27.16,
#   'Humidity': 76,
#   'Cloudiness': 9,
#   'Wind Speed': 2.86,
#   'Country': 'YE',
#   'Date': 1712783543},
#  {'City': 'sur',
#   'Lat': 22.5667,
#   'Lng': 59.5289,
#   'Max Temp': 29.56,
#   'Humidity': 50,
#   'Cloudiness': 93,
#   'Wind Speed': 1.36,
#   'Country': 'OM',
#   'Date': 1712783716},
#  {'City': 'coquimbo',
#   'Lat': -29.9533,
#   'Lng': -71.3436,
#   'Max Temp': 16.56,
#   'Humidity': 79,
#   'Cloudiness': 100,
#   'Wind Speed': 2.5,
#   'Country': 'CL',
#   'Date': 1712783434},
#  {'City': 'fortuna',
#   'Lat': 40.5982,
#   'Lng': -124.1573,
#   'Max Temp': 17.18,
#   'Humidity': 85,
#   'Cloudiness': 0,
#   'Wind Speed': 6.69,
#   'Country': 'US',
#   'Date': 1712783434},
#  {'City': 'santa terezinha',
#   'Lat': -29.9002,
#   'Lng': -50.0904,
#   'Max Temp': 22.33,
#   'Humidity': 85,
#   'Cloudiness': 100,
#   'Wind Speed': 4.43,
#   'Country': 'BR',
#   'Date': 1712783717},
#  {'City': 'tazovsky',
#   'Lat': 67.4667,
#   'Lng': 78.7,
#   'Max Temp': -31.15,
#   'Humidity': 100,
#   'Cloudiness': 65,
#   'Wind Speed': 2.65,
#   'Country': 'RU',
#   'Date': 1712783717},
#  {'City': 'dudinka',
#   'Lat': 69.4058,
#   'Lng': 86.1778,
#   'Max Temp': -31.29,
#   'Humidity': 100,
#   'Cloudiness': 100,
#   'Wind Speed': 1.79,
#   'Country': 'RU',
#   'Date': 1712783717},
#  {'City': 'flying fish cove',
#   'Lat': -10.4217,
#   'Lng': 105.6791,
#   'Max Temp': 25.82,
#   'Humidity': 88,
#   'Cloudiness': 75,
#   'Wind Speed': 3.09,
#   'Country': 'CX',
#   'Date': 1712783717},
#  {'City': 'sandnessjoen',
#   'Lat': 66.0217,
#   'Lng': 12.6316,
#   'Max Temp': 5.29,
#   'Humidity': 87,
#   'Cloudiness': 75,
#   'Wind Speed': 7.72,
#   'Country': 'NO',
#   'Date': 1712783717},
#  {'City': 'tsengel',
#   'Lat': 49.4783,
#   'Lng': 100.8894,
#   'Max Temp': 2.99,
#   'Humidity': 45,
#   'Cloudiness': 57,
#   'Wind Speed': 1.98,
#   'Country': 'MN',
#   'Date': 1712783717},
#  {'City': 'kokstad',
#   'Lat': -30.5472,
#   'Lng': 29.4241,
#   'Max Temp': 10.28,
#   'Humidity': 91,
#   'Cloudiness': 95,
#   'Wind Speed': 3.57,
#   'Country': 'ZA',
#   'Date': 1712783717},
#  {'City': 'albany',
#   'Lat': 42.6001,
#   'Lng': -73.9662,
#   'Max Temp': 13.15,
#   'Humidity': 83,
#   'Cloudiness': 100,
#   'Wind Speed': 0.45,
#   'Country': 'US',
#   'Date': 1712783660},
#  {'City': 'kapuskasing',
#   'Lat': 49.4169,
#   'Lng': -82.4331,
#   'Max Temp': 10.44,
#   'Humidity': 75,
#   'Cloudiness': 95,
#   'Wind Speed': 2.19,
#   'Country': 'CA',
#   'Date': 1712783642},
#  {'City': 'la paz',
#   'Lat': -16.5,
#   'Lng': -68.15,
#   'Max Temp': 15.99,
#   'Humidity': 58,
#   'Cloudiness': 75,
#   'Wind Speed': 3.09,
#   'Country': 'BO',
#   'Date': 1712783318},
#  {'City': 'fray luis beltran',
#   'Lat': -39.3167,
#   'Lng': -65.7667,
#   'Max Temp': 16.12,
#   'Humidity': 18,
#   'Cloudiness': 100,
#   'Wind Speed': 4.53,
#   'Country': 'AR',
#   'Date': 1712783718},
#  {'City': 'sao paulo de olivenca',
#   'Lat': -3.3783,
#   'Lng': -68.8725,
#   'Max Temp': 26.64,
#   'Humidity': 94,
#   'Cloudiness': 100,
#   'Wind Speed': 0.46,
#   'Country': 'BR',
#   'Date': 1712783484},
#  {'City': 'montpelier',
#   'Lat': 44.2601,
#   'Lng': -72.5754,
#   'Max Temp': 11.92,
#   'Humidity': 77,
#   'Cloudiness': 100,
#   'Wind Speed': 2.06,
#   'Country': 'US',
#   'Date': 1712783621},
#  {'City': 'howrah',
#   'Lat': 22.5892,
#   'Lng': 88.3103,
#   'Max Temp': 25,
#   'Humidity': 83,
#   'Cloudiness': 40,
#   'Wind Speed': 0,
#   'Country': 'IN',
#   'Date': 1712783718},
#  {'City': 'charcas',
#   'Lat': 23.1333,
#   'Lng': -101.1167,
#   'Max Temp': 22.42,
#   'Humidity': 10,
#   'Cloudiness': 5,
#   'Wind Speed': 7.84,
#   'Country': 'MX',
#   'Date': 1712783718},
#  {'City': 'itumba',
#   'Lat': -9.4,
#   'Lng': 33.1833,
#   'Max Temp': 17.64,
#   'Humidity': 95,
#   'Cloudiness': 88,
#   'Wind Speed': 1.49,
#   'Country': 'TZ',
#   'Date': 1712783719},
#  {'City': 'saipan',
#   'Lat': 15.1355,
#   'Lng': 145.701,
#   'Max Temp': 27.39,
#   'Humidity': 74,
#   'Cloudiness': 20,
#   'Wind Speed': 7.2,
#   'Country': 'MP',
#   'Date': 1712783719},
#  {'City': 'college',
#   'Lat': 64.8569,
#   'Lng': -147.8028,
#   'Max Temp': 4.49,
#   'Humidity': 50,
#   'Cloudiness': 0,
#   'Wind Speed': 0.45,
#   'Country': 'US',
#   'Date': 1712783719},
#  {'City': 'qorveh',
#   'Lat': 35.1664,
#   'Lng': 47.8045,
#   'Max Temp': 6.71,
#   'Humidity': 78,
#   'Cloudiness': 100,
#   'Wind Speed': 2.48,
#   'Country': 'IR',
#   'Date': 1712783719},
#  {'City': 'houlton',
#   'Lat': 46.1262,
#   'Lng': -67.8403,
#   'Max Temp': 10.23,
#   'Humidity': 40,
#   'Cloudiness': 75,
#   'Wind Speed': 3.6,
#   'Country': 'US',
#   'Date': 1712783719},
#  {'City': 'port douglas',
#   'Lat': -16.4833,
#   'Lng': 145.4667,
#   'Max Temp': 24.62,
#   'Humidity': 85,
#   'Cloudiness': 59,
#   'Wind Speed': 3.59,
#   'Country': 'AU',
#   'Date': 1712783719},
#  {'City': 'chimoio',
#   'Lat': -19.1164,
#   'Lng': 33.4833,
#   'Max Temp': 21.1,
#   'Humidity': 96,
#   'Cloudiness': 87,
#   'Wind Speed': 1.99,
#   'Country': 'MZ',
#   'Date': 1712783574},
#  {'City': 'itamaraca',
#   'Lat': -7.7478,
#   'Lng': -34.8256,
#   'Max Temp': 28.03,
#   'Humidity': 80,
#   'Cloudiness': 100,
#   'Wind Speed': 2.58,
#   'Country': 'BR',
#   'Date': 1712783537},
#  {'City': 'grand falls-windsor',
#   'Lat': 48.9332,
#   'Lng': -55.6649,
#   'Max Temp': 0.84,
#   'Humidity': 74,
#   'Cloudiness': 87,
#   'Wind Speed': 1.79,
#   'Country': 'CA',
#   'Date': 1712783719},
#  {'City': 'praia da vitoria',
#   'Lat': 38.7333,
#   'Lng': -27.0667,
#   'Max Temp': 17.64,
#   'Humidity': 96,
#   'Cloudiness': 91,
#   'Wind Speed': 7.27,
#   'Country': 'PT',
#   'Date': 1712783720},
#  {'City': 'nybro',
#   'Lat': 56.7446,
#   'Lng': 15.9071,
#   'Max Temp': 7.8,
#   'Humidity': 64,
#   'Cloudiness': 37,
#   'Wind Speed': 4.73,
#   'Country': 'SE',
#   'Date': 1712783720},
#  {'City': 'al ghayzah',
#   'Lat': 16.2079,
#   'Lng': 52.176,
#   'Max Temp': 26.6,
#   'Humidity': 74,
#   'Cloudiness': 2,
#   'Wind Speed': 3.38,
#   'Country': 'YE',
#   'Date': 1712783720},
#  {'City': 'brigantine',
#   'Lat': 39.4101,
#   'Lng': -74.3646,
#   'Max Temp': 23.44,
#   'Humidity': 74,
#   'Cloudiness': 100,
#   'Wind Speed': 3.6,
#   'Country': 'US',
#   'Date': 1712783706},
#  {'City': 'bambanglipuro',
#   'Lat': -7.95,
#   'Lng': 110.2833,
#   'Max Temp': 24.75,
#   'Humidity': 94,
#   'Cloudiness': 95,
#   'Wind Speed': 1.49,
#   'Country': 'ID',
#   'Date': 1712783720},
#  {'City': 'revda',
#   'Lat': 56.801,
#   'Lng': 59.9303,
#   'Max Temp': -1.44,
#   'Humidity': 92,
#   'Cloudiness': 57,
#   'Wind Speed': 1.63,
#   'Country': 'RU',
#   'Date': 1712783720},
#  {'City': 'weno',
#   'Lat': 7.4515,
#   'Lng': 151.8468,
#   'Max Temp': 26.97,
#   'Humidity': 100,
#   'Cloudiness': 100,
#   'Wind Speed': 4.12,
#   'Country': 'FM',
#   'Date': 1712783721},
#  {'City': 'hotan',
#   'Lat': 37.0997,
#   'Lng': 79.9269,
#   'Max Temp': 15.34,
#   'Humidity': 16,
#   'Cloudiness': 59,
#   'Wind Speed': 0.74,
#   'Country': 'CN',
#   'Date': 1712783721},
#  {'City': 'west island',
#   'Lat': -12.1568,
#   'Lng': 96.8225,
#   'Max Temp': 25.99,
#   'Humidity': 73,
#   'Cloudiness': 63,
#   'Wind Speed': 2.57,
#   'Country': 'CC',
#   'Date': 1712783721},
#  {'City': 'prien',
#   'Lat': 30.1819,
#   'Lng': -93.2738,
#   'Max Temp': 24.99,
#   'Humidity': 73,
#   'Cloudiness': 0,
#   'Wind Speed': 7.72,
#   'Country': 'US',
#   'Date': 1712783721},
#  {'City': 'lamu',
#   'Lat': -2.2717,
#   'Lng': 40.902,
#   'Max Temp': 28.49,
#   'Humidity': 84,
#   'Cloudiness': 100,
#   'Wind Speed': 3.75,
#   'Country': 'KE',
#   'Date': 1712783721},
#  {'City': 'mata-utu',
#   'Lat': -13.2816,
#   'Lng': -176.1745,
#   'Max Temp': 29.43,
#   'Humidity': 77,
#   'Cloudiness': 23,
#   'Wind Speed': 5.46,
#   'Country': 'WF',
#   'Date': 1712783721},
#  {'City': 'avarua',
#   'Lat': -21.2078,
#   'Lng': -159.775,
#   'Max Temp': 28.03,
#   'Humidity': 83,
#   'Cloudiness': 75,
#   'Wind Speed': 10.8,
#   'Country': 'CK',
#   'Date': 1712783721},
#  {'City': 'itaituba',
#   'Lat': -4.2761,
#   'Lng': -55.9836,
#   'Max Temp': 26.68,
#   'Humidity': 94,
#   'Cloudiness': 90,
#   'Wind Speed': 1.35,
#   'Country': 'BR',
#   'Date': 1712783721},
#  {'City': 'kununurra',
#   'Lat': -15.7667,
#   'Lng': 128.7333,
#   'Max Temp': 16.99,
#   'Humidity': 82,
#   'Cloudiness': 27,
#   'Wind Speed': 0.51,
#   'Country': 'AU',
#   'Date': 1712783722},
#  {'City': 'brookings',
#   'Lat': 44.3114,
#   'Lng': -96.7984,
#   'Max Temp': 19.14,
#   'Humidity': 36,
#   'Cloudiness': 100,
#   'Wind Speed': 5.66,
#   'Country': 'US',
#   'Date': 1712783722},
#  {'City': 'bermejo',
#   'Lat': -32.8833,
#   'Lng': -68.8,
#   'Max Temp': 12.18,
#   'Humidity': 52,
#   'Cloudiness': 64,
#   'Wind Speed': 6.54,
#   'Country': 'AR',
#   'Date': 1712783722},
#  {'City': 'new norfolk',
#   'Lat': -42.7826,
#   'Lng': 147.0587,
#   'Max Temp': 8.73,
#   'Humidity': 90,
#   'Cloudiness': 85,
#   'Wind Speed': 0.55,
#   'Country': 'AU',
#   'Date': 1712783722},
#  {'City': 'pemangkat',
#   'Lat': 1.1667,
#   'Lng': 108.9667,
#   'Max Temp': 25.46,
#   'Humidity': 90,
#   'Cloudiness': 99,
#   'Wind Speed': 2.84,
#   'Country': 'ID',
#   'Date': 1712783722},
#  {'City': 'holualoa',
#   'Lat': 19.6228,
#   'Lng': -155.9522,
#   'Max Temp': 24.91,
#   'Humidity': 84,
#   'Cloudiness': 40,
#   'Wind Speed': 5.66,
#   'Country': 'US',
#   'Date': 1712783722},
#  {'City': 'zaozersk',
#   'Lat': 69.4005,
#   'Lng': 32.4476,
#   'Max Temp': 3.08,
#   'Humidity': 96,
#   'Cloudiness': 100,
#   'Wind Speed': 8.58,
#   'Country': 'RU',
#   'Date': 1712783722},
#  {'City': 'isafjordur',
#   'Lat': 66.0755,
#   'Lng': -23.124,
#   'Max Temp': -3.81,
#   'Humidity': 87,
#   'Cloudiness': 38,
#   'Wind Speed': 2.53,
#   'Country': 'IS',
#   'Date': 1712783722},
#  {'City': 'kievka',
#   'Lat': 50.2619,
#   'Lng': 71.5514,
#   'Max Temp': 3.28,
#   'Humidity': 80,
#   'Cloudiness': 100,
#   'Wind Speed': 3.27,
#   'Country': 'KZ',
#   'Date': 1712783723},
#  {'City': 'plast',
#   'Lat': 54.3691,
#   'Lng': 60.8136,
#   'Max Temp': 3.23,
#   'Humidity': 87,
#   'Cloudiness': 100,
#   'Wind Speed': 0.6,
#   'Country': 'RU',
#   'Date': 1712783723},
#  {'City': 'erdenet',
#   'Lat': 49.0333,
#   'Lng': 104.0833,
#   'Max Temp': 4.42,
#   'Humidity': 46,
#   'Cloudiness': 100,
#   'Wind Speed': 2.51,
#   'Country': 'MN',
#   'Date': 1712783723},
#  {'City': 'sinop',
#   'Lat': 41.7711,
#   'Lng': 34.8709,
#   'Max Temp': 11.55,
#   'Humidity': 72,
#   'Cloudiness': 100,
#   'Wind Speed': 1.81,
#   'Country': 'TR',
#   'Date': 1712783723},
#  {'City': 'dwarka',
#   'Lat': 22.2394,
#   'Lng': 68.9678,
#   'Max Temp': 25.72,
#   'Humidity': 77,
#   'Cloudiness': 100,
#   'Wind Speed': 4.87,
#   'Country': 'IN',
#   'Date': 1712783724},
#  {'City': 'carnarvon',
#   'Lat': -24.8667,
#   'Lng': 113.6333,
#   'Max Temp': 23.59,
#   'Humidity': 58,
#   'Cloudiness': 0,
#   'Wind Speed': 3.7,
#   'Country': 'AU',
#   'Date': 1712783475},
#  {'City': 'orumiyeh',
#   'Lat': 37.5527,
#   'Lng': 45.0761,
#   'Max Temp': 8.54,
#   'Humidity': 86,
#   'Cloudiness': 100,
#   'Wind Speed': 0.97,
#   'Country': 'IR',
#   'Date': 1712783724},
#  {'City': 'usinsk',
#   'Lat': 65.9939,
#   'Lng': 57.5281,
#   'Max Temp': -16.63,
#   'Humidity': 93,
#   'Cloudiness': 65,
#   'Wind Speed': 3.58,
#   'Country': 'RU',
#   'Date': 1712783724},
#  {'City': 'keflavik',
#   'Lat': 64.0049,
#   'Lng': -22.5624,
#   'Max Temp': 4.24,
#   'Humidity': 81,
#   'Cloudiness': 100,
#   'Wind Speed': 3.09,
#   'Country': 'IS',
#   'Date': 1712783724},
#  {'City': 'sirte',
#   'Lat': 31.2089,
#   'Lng': 16.5887,
#   'Max Temp': 17.53,
#   'Humidity': 75,
#   'Cloudiness': 0,
#   'Wind Speed': 3.52,
#   'Country': 'LY',
#   'Date': 1712783724},
#  {'City': 'vorkuta',
#   'Lat': 67.5,
#   'Lng': 64,
#   'Max Temp': -25.31,
#   'Humidity': 100,
#   'Cloudiness': 100,
#   'Wind Speed': 1.45,
#   'Country': 'RU',
#   'Date': 1712783724},
#  {'City': 'daru',
#   'Lat': -9.0763,
#   'Lng': 143.2092,
#   'Max Temp': 26.1,
#   'Humidity': 89,
#   'Cloudiness': 81,
#   'Wind Speed': 3.35,
#   'Country': 'PG',
#   'Date': 1712783724},
#  {'City': 'lysyye gory',
#   'Lat': 51.5506,
#   'Lng': 44.8414,
#   'Max Temp': 12.89,
#   'Humidity': 88,
#   'Cloudiness': 1,
#   'Wind Speed': 3.56,
#   'Country': 'RU',
#   'Date': 1712783724},
#  {'City': 'hamilton',
#   'Lat': 39.1834,
#   'Lng': -84.5333,
#   'Max Temp': 17.74,
#   'Humidity': 93,
#   'Cloudiness': 100,
#   'Wind Speed': 3.09,
#   'Country': 'US',
#   'Date': 1712783488},
#  {'City': 'novogrudok',
#   'Lat': 53.6,
#   'Lng': 25.8333,
#   'Max Temp': 9.58,
#   'Humidity': 68,
#   'Cloudiness': 100,
#   'Wind Speed': 6.37,
#   'Country': 'BY',
#   'Date': 1712783725},
#  {'City': 'kerikeri',
#   'Lat': -35.2268,
#   'Lng': 173.9474,
#   'Max Temp': 21.62,
#   'Humidity': 88,
#   'Cloudiness': 100,
#   'Wind Speed': 7.11,
#   'Country': 'NZ',
#   'Date': 1712783725},
#  {'City': 'san patricio',
#   'Lat': 28.017,
#   'Lng': -97.5169,
#   'Max Temp': 27.17,
#   'Humidity': 30,
#   'Cloudiness': 0,
#   'Wind Speed': 12.19,
#   'Country': 'US',
#   'Date': 1712783725},
#  {'City': 'ilulissat',
#   'Lat': 69.2167,
#   'Lng': -51.1,
#   'Max Temp': -4.99,
#   'Humidity': 58,
#   'Cloudiness': 100,
#   'Wind Speed': 2.57,
#   'Country': 'GL',
#   'Date': 1712783725},
#  {'City': 'talnakh',
#   'Lat': 69.4865,
#   'Lng': 88.3972,
#   'Max Temp': -31.99,
#   'Humidity': 99,
#   'Cloudiness': 81,
#   'Wind Speed': 1.75,
#   'Country': 'RU',
#   'Date': 1712783725},
#  {'City': 'saanen',
#   'Lat': 46.4896,
#   'Lng': 7.2596,
#   'Max Temp': 5.43,
#   'Humidity': 97,
#   'Cloudiness': 26,
#   'Wind Speed': 1.94,
#   'Country': 'CH',
#   'Date': 1712783725},
#  {'City': 'kurumkan',
#   'Lat': 54.3,
#   'Lng': 110.3,
#   'Max Temp': 2.85,
#   'Humidity': 48,
#   'Cloudiness': 100,
#   'Wind Speed': 1.34,
#   'Country': 'RU',
#   'Date': 1712783725},
#  {'City': 'whitehorse',
#   'Lat': 60.7161,
#   'Lng': -135.0538,
#   'Max Temp': 1.69,
#   'Humidity': 74,
#   'Cloudiness': 100,
#   'Wind Speed': 3.31,
#   'Country': 'CA',
#   'Date': 1712783600},
#  {'City': 'nizhneudinsk',
#   'Lat': 54.9076,
#   'Lng': 99.0276,
#   'Max Temp': 2.22,
#   'Humidity': 97,
#   'Cloudiness': 100,
#   'Wind Speed': 1.81,
#   'Country': 'RU',
#   'Date': 1712783726},
#  {'City': 'shache',
#   'Lat': 38.4167,
#   'Lng': 77.2406,
#   'Max Temp': 16.87,
#   'Humidity': 14,
#   'Cloudiness': 100,
#   'Wind Speed': 3.08,
#   'Country': 'CN',
#   'Date': 1712783726},
#  {'City': 'puerto ayora',
#   'Lat': -0.7393,
#   'Lng': -90.3518,
#   'Max Temp': 28.98,
#   'Humidity': 91,
#   'Cloudiness': 59,
#   'Wind Speed': 2.68,
#   'Country': 'EC',
#   'Date': 1712783726},
#  {'City': 'cockburn town',
#   'Lat': 21.4612,
#   'Lng': -71.1419,
#   'Max Temp': 25.09,
#   'Humidity': 70,
#   'Cloudiness': 5,
#   'Wind Speed': 10.34,
#   'Country': 'TC',
#   'Date': 1712783522},
#  {'City': 'emerald',
#   'Lat': -23.5333,
#   'Lng': 148.1667,
#   'Max Temp': 13.52,
#   'Humidity': 68,
#   'Cloudiness': 0,
#   'Wind Speed': 4.86,
#   'Country': 'AU',
#   'Date': 1712783726},
#  {'City': 'battagram',
#   'Lat': 34.6772,
#   'Lng': 73.0233,
#   'Max Temp': 15.34,
#   'Humidity': 67,
#   'Cloudiness': 100,
#   'Wind Speed': 3.38,
#   'Country': 'PK',
#   'Date': 1712783726},
#  {'City': 'san luis de la loma',
#   'Lat': 17.2706,
#   'Lng': -100.8939,
#   'Max Temp': 29.47,
#   'Humidity': 57,
#   'Cloudiness': 0,
#   'Wind Speed': 5.42,
#   'Country': 'MX',
#   'Date': 1712783727},
#  {'City': 'darwin',
#   'Lat': -12.4611,
#   'Lng': 130.8418,
#   'Max Temp': 22.19,
#   'Humidity': 68,
#   'Cloudiness': 100,
#   'Wind Speed': 3.6,
#   'Country': 'AU',
#   'Date': 1712782952},
#  {'City': 'longyearbyen',
#   'Lat': 78.2186,
#   'Lng': 15.6401,
#   'Max Temp': -16.09,
#   'Humidity': 78,
#   'Cloudiness': 20,
#   'Wind Speed': 4.12,
#   'Country': 'SJ',
#   'Date': 1712783622},
#  {'City': 'fauske',
#   'Lat': 67.2588,
#   'Lng': 15.3918,
#   'Max Temp': 5.02,
#   'Humidity': 100,
#   'Cloudiness': 100,
#   'Wind Speed': 2.8,
#   'Country': 'NO',
#   'Date': 1712783727},
#  {'City': 'vilyuchinsk',
#   'Lat': 52.9306,
#   'Lng': 158.4028,
#   'Max Temp': 3.15,
#   'Humidity': 71,
#   'Cloudiness': 90,
#   'Wind Speed': 15.48,
#   'Country': 'RU',
#   'Date': 1712783727},
#  {'City': 'arraial do cabo',
#   'Lat': -22.9661,
#   'Lng': -42.0278,
#   'Max Temp': 25.92,
#   'Humidity': 83,
#   'Cloudiness': 40,
#   'Wind Speed': 4.63,
#   'Country': 'BR',
#   'Date': 1712783727},
#  {'City': 'enewetak',
#   'Lat': 11.3474,
#   'Lng': 162.3373,
#   'Max Temp': 27.12,
#   'Humidity': 81,
#   'Cloudiness': 100,
#   'Wind Speed': 9.77,
#   'Country': 'MH',
#   'Date': 1712783727},
#  {'City': 'tucumcari',
#   'Lat': 35.1717,
#   'Lng': -103.725,
#   'Max Temp': 18.3,
#   'Humidity': 36,
#   'Cloudiness': 75,
#   'Wind Speed': 2.57,
#   'Country': 'US',
#   'Date': 1712783727},
#  {'City': 'vadso',
#   'Lat': 70.0744,
#   'Lng': 29.7487,
#   'Max Temp': 4.49,
#   'Humidity': 100,
#   'Cloudiness': 75,
#   'Wind Speed': 4.63,
#   'Country': 'NO',
#   'Date': 1712783727},
#  {'City': 'kerteminde',
#   'Lat': 55.449,
#   'Lng': 10.6577,
#   'Max Temp': 8.87,
#   'Humidity': 85,
#   'Cloudiness': 99,
#   'Wind Speed': 6.28,
#   'Country': 'DK',
#   'Date': 1712783728},
#  {'City': 'argo',
#   'Lat': 37.6333,
#   'Lng': 22.7333,
#   'Max Temp': 16.28,
#   'Humidity': 49,
#   'Cloudiness': 100,
#   'Wind Speed': 1.57,
#   'Country': 'GR',
#   'Date': 1712783728},
#  {'City': 'lorengau',
#   'Lat': -2.0226,
#   'Lng': 147.2712,
#   'Max Temp': 26.3,
#   'Humidity': 83,
#   'Cloudiness': 100,
#   'Wind Speed': 0.44,
#   'Country': 'PG',
#   'Date': 1712783728},
#  {'City': 'badger',
#   'Lat': 64.8,
#   'Lng': -147.5333,
#   'Max Temp': 4.44,
#   'Humidity': 50,
#   'Cloudiness': 20,
#   'Wind Speed': 0.89,
#   'Country': 'US',
#   'Date': 1712783728},
#  {'City': 'sitka',
#   'Lat': 57.0531,
#   'Lng': -135.33,
#   'Max Temp': 7.94,
#   'Humidity': 61,
#   'Cloudiness': 100,
#   'Wind Speed': 6.17,
#   'Country': 'US',
#   'Date': 1712783556},
#  {'City': 'barakani',
#   'Lat': -12.1356,
#   'Lng': 44.4317,
#   'Max Temp': 28.3,
#   'Humidity': 80,
#   'Cloudiness': 86,
#   'Wind Speed': 2.49,
#   'Country': 'KM',
#   'Date': 1712783728},
#  {'City': 'tosontsengel',
#   'Lat': 48.7567,
#   'Lng': 98.2839,
#   'Max Temp': 1.84,
#   'Humidity': 52,
#   'Cloudiness': 83,
#   'Wind Speed': 4.25,
#   'Country': 'MN',
#   'Date': 1712783728},
#  {'City': 'urangan',
#   'Lat': -25.3,
#   'Lng': 152.9,
#   'Max Temp': 16.22,
#   'Humidity': 77,
#   'Cloudiness': 0,
#   'Wind Speed': 2.68,
#   'Country': 'AU',
#   'Date': 1712783728},
#  {'City': 'puerto baquerizo moreno',
#   'Lat': -0.9,
#   'Lng': -89.6,
#   'Max Temp': 28.55,
#   'Humidity': 74,
#   'Cloudiness': 40,
#   'Wind Speed': 3.09,
#   'Country': 'EC',
#   'Date': 1712783728},
#  {'City': 'north platte',
#   'Lat': 41.1239,
#   'Lng': -100.7654,
#   'Max Temp': 17.94,
#   'Humidity': 31,
#   'Cloudiness': 40,
#   'Wind Speed': 7.72,
#   'Country': 'US',
#   'Date': 1712783729},
#  {'City': 'rugaji',
#   'Lat': 57,
#   'Lng': 27.1333,
#   'Max Temp': 10.61,
#   'Humidity': 68,
#   'Cloudiness': 96,
#   'Wind Speed': 5.41,
#   'Country': 'LV',
#   'Date': 1712783729},
#  {'City': 'phalodi',
#   'Lat': 27.1333,
#   'Lng': 72.3667,
#   'Max Temp': 29.2,
#   'Humidity': 17,
#   'Cloudiness': 67,
#   'Wind Speed': 5.02,
#   'Country': 'IN',
#   'Date': 1712783729},
#  {'City': 'fale old settlement',
#   'Lat': -9.3852,
#   'Lng': -171.2468,
#   'Max Temp': 30,
#   'Humidity': 75,
#   'Cloudiness': 49,
#   'Wind Speed': 5.29,
#   'Country': 'TK',
#   'Date': 1712783729},
#  {'City': 'kourou',
#   'Lat': 5.1552,
#   'Lng': -52.6478,
#   'Max Temp': 29.03,
#   'Humidity': 87,
#   'Cloudiness': 92,
#   'Wind Speed': 4.19,
#   'Country': 'GF',
#   'Date': 1712783729},
#  {'City': 'waddan',
#   'Lat': 29.1614,
#   'Lng': 16.139,
#   'Max Temp': 19.46,
#   'Humidity': 22,
#   'Cloudiness': 0,
#   'Wind Speed': 5.88,
#   'Country': 'LY',
#   'Date': 1712783729},
#  {'City': 'gangtok',
#   'Lat': 27.3333,
#   'Lng': 88.6167,
#   'Max Temp': 14.37,
#   'Humidity': 48,
#   'Cloudiness': 3,
#   'Wind Speed': 3.39,
#   'Country': 'IN',
#   'Date': 1712783729},
#  {'City': 'aleg',
#   'Lat': 17.0481,
#   'Lng': -13.9209,
#   'Max Temp': 33.37,
#   'Humidity': 13,
#   'Cloudiness': 0,
#   'Wind Speed': 4.65,
#   'Country': 'MR',
#   'Date': 1712783730},
#  {'City': 'oriximina',
#   'Lat': -1.7656,
#   'Lng': -55.8661,
#   'Max Temp': 28.46,
#   'Humidity': 85,
#   'Cloudiness': 44,
#   'Wind Speed': 0.7,
#   'Country': 'BR',
#   'Date': 1712783730},
#  {'City': 'vilyuysk',
#   'Lat': 63.7553,
#   'Lng': 121.6247,
#   'Max Temp': 0.56,
#   'Humidity': 94,
#   'Cloudiness': 100,
#   'Wind Speed': 5.36,
#   'Country': 'RU',
#   'Date': 1712783533},
#  {'City': "nar'yan-mar",
#   'Lat': 67.6713,
#   'Lng': 53.087,
#   'Max Temp': -13.83,
#   'Humidity': 96,
#   'Cloudiness': 100,
#   'Wind Speed': 2.68,
#   'Country': 'RU',
#   'Date': 1712783730},
#  {'City': 'sitia',
#   'Lat': 35.2,
#   'Lng': 26.0986,
#   'Max Temp': 16.46,
#   'Humidity': 59,
#   'Cloudiness': 21,
#   'Wind Speed': 3.59,
#   'Country': 'GR',
#   'Date': 1712783730},
#  {'City': 'hermanus',
#   'Lat': -34.4187,
#   'Lng': 19.2345,
#   'Max Temp': 15.45,
#   'Humidity': 72,
#   'Cloudiness': 26,
#   'Wind Speed': 8.49,
#   'Country': 'ZA',
#   'Date': 1712783730},
#  {'City': 'lompoc',
#   'Lat': 34.6391,
#   'Lng': -120.4579,
#   'Max Temp': 28.77,
#   'Humidity': 59,
#   'Cloudiness': 0,
#   'Wind Speed': 6.17,
#   'Country': 'US',
#   'Date': 1712783664},
#  {'City': 'gabu',
#   'Lat': 12.2833,
#   'Lng': -14.2167,
#   'Max Temp': 32,
#   'Humidity': 26,
#   'Cloudiness': 0,
#   'Wind Speed': 4.56,
#   'Country': 'GW',
#   'Date': 1712783730},
#  {'City': 'touros',
#   'Lat': -5.1989,
#   'Lng': -35.4608,
#   'Max Temp': 26.66,
#   'Humidity': 85,
#   'Cloudiness': 100,
#   'Wind Speed': 2.29,
#   'Country': 'BR',
#   'Date': 1712783448},
#  {'City': 'luderitz',
#   'Lat': -26.6481,
#   'Lng': 15.1594,
#   'Max Temp': 20.02,
#   'Humidity': 57,
#   'Cloudiness': 0,
#   'Wind Speed': 6.73,
#   'Country': 'NA',
#   'Date': 1712783560},
#  {'City': 'broken hill',
#   'Lat': -31.95,
#   'Lng': 141.4333,
#   'Max Temp': 9.93,
#   'Humidity': 82,
#   'Cloudiness': 0,
#   'Wind Speed': 4.12,
#   'Country': 'AU',
#   'Date': 1712783731},
#  {'City': 'rakops',
#   'Lat': -21.0167,
#   'Lng': 24.3333,
#   'Max Temp': 22.11,
#   'Humidity': 32,
#   'Cloudiness': 100,
#   'Wind Speed': 3.38,
#   'Country': 'BW',
#   'Date': 1712783486},
#  {'City': 'callao',
#   'Lat': -12.0667,
#   'Lng': -77.15,
#   'Max Temp': 25.16,
#   'Humidity': 69,
#   'Cloudiness': 0,
#   'Wind Speed': 4.12,
#   'Country': 'PE',
#   'Date': 1712783731},
#  {'City': 'fruita',
#   'Lat': 39.1589,
#   'Lng': -108.729,
#   'Max Temp': 18.65,
#   'Humidity': 20,
#   'Cloudiness': 20,
#   'Wind Speed': 3.6,
#   'Country': 'US',
#   'Date': 1712783731},
#  {'City': 'constitucion',
#   'Lat': -35.3333,
#   'Lng': -72.4167,
#   'Max Temp': 16.26,
#   'Humidity': 52,
#   'Cloudiness': 68,
#   'Wind Speed': 3.79,
#   'Country': 'CL',
#   'Date': 1712783731},
#  {'City': 'pauini',
#   'Lat': -7.7136,
#   'Lng': -66.9764,
#   'Max Temp': 24.86,
#   'Humidity': 92,
#   'Cloudiness': 100,
#   'Wind Speed': 1.15,
#   'Country': 'BR',
#   'Date': 1712783731},
#  {'City': 'santanyi',
#   'Lat': 39.3546,
#   'Lng': 3.1291,
#   'Max Temp': 12.66,
#   'Humidity': 78,
#   'Cloudiness': 1,
#   'Wind Speed': 3.7,
#   'Country': 'ES',
#   'Date': 1712783732},
#  {'City': 'xiaoshan',
#   'Lat': 30.1675,
#   'Lng': 120.2588,
#   'Max Temp': 16.58,
#   'Humidity': 88,
#   'Cloudiness': 40,
#   'Wind Speed': 1,
#   'Country': 'CN',
#   'Date': 1712783732},
#  {'City': 'oranjemund',
#   'Lat': -28.55,
#   'Lng': 16.4333,
#   'Max Temp': 15.77,
#   'Humidity': 83,
#   'Cloudiness': 0,
#   'Wind Speed': 6.06,
#   'Country': 'NA',
#   'Date': 1712783732},
#  {'City': 'shagonar',
#   'Lat': 51.5333,
#   'Lng': 92.8,
#   'Max Temp': 4.43,
#   'Humidity': 81,
#   'Cloudiness': 95,
#   'Wind Speed': 1.48,
#   'Country': 'RU',
#   'Date': 1712783732},
#  {'City': 'nizhniy odes',
#   'Lat': 63.6445,
#   'Lng': 54.856,
#   'Max Temp': -8.83,
#   'Humidity': 100,
#   'Cloudiness': 94,
#   'Wind Speed': 0.68,
#   'Country': 'RU',
#   'Date': 1712783732},
#  {'City': 'galliano',
#   'Lat': 29.4422,
#   'Lng': -90.2992,
#   'Max Temp': 25,
#   'Humidity': 78,
#   'Cloudiness': 0,
#   'Wind Speed': 4.63,
#   'Country': 'US',
#   'Date': 1712783433},
#  {'City': 'ust-nera',
#   'Lat': 64.5667,
#   'Lng': 143.2,
#   'Max Temp': -13.4,
#   'Humidity': 96,
#   'Cloudiness': 81,
#   'Wind Speed': 2.6,
#   'Country': 'RU',
#   'Date': 1712783732},
#  {'City': 'luganville',
#   'Lat': -15.5333,
#   'Lng': 167.1667,
#   'Max Temp': 26.97,
#   'Humidity': 86,
#   'Cloudiness': 57,
#   'Wind Speed': 0.19,
#   'Country': 'VU',
#   'Date': 1712783732},
#  {'City': 'uturoa',
#   'Lat': -16.7333,
#   'Lng': -151.4333,
#   'Max Temp': 29.13,
#   'Humidity': 77,
#   'Cloudiness': 25,
#   'Wind Speed': 8.68,
#   'Country': 'PF',
#   'Date': 1712783732},
#  {'City': 'murun-kuren',
#   'Lat': 49.6342,
#   'Lng': 100.1625,
#   'Max Temp': 3.22,
#   'Humidity': 46,
#   'Cloudiness': 86,
#   'Wind Speed': 1.36,
#   'Country': 'MN',
#   'Date': 1712783733},
#  {'City': 'blackburn south',
#   'Lat': -37.8397,
#   'Lng': 145.1555,
#   'Max Temp': 13.67,
#   'Humidity': 92,
#   'Cloudiness': 99,
#   'Wind Speed': 1.67,
#   'Country': 'AU',
#   'Date': 1712783733},
#  {'City': 'nyurba',
#   'Lat': 63.2842,
#   'Lng': 118.3319,
#   'Max Temp': -1.24,
#   'Humidity': 98,
#   'Cloudiness': 100,
#   'Wind Speed': 2.23,
#   'Country': 'RU',
#   'Date': 1712783572},
#  {'City': 'belorechensk',
#   'Lat': 44.76,
#   'Lng': 39.87,
#   'Max Temp': 17.04,
#   'Humidity': 73,
#   'Cloudiness': 93,
#   'Wind Speed': 3.42,
#   'Country': 'RU',
#   'Date': 1712783733},
#  {'City': 'krasnyye baki',
#   'Lat': 57.131,
#   'Lng': 45.1599,
#   'Max Temp': 7.48,
#   'Humidity': 83,
#   'Cloudiness': 21,
#   'Wind Speed': 2.84,
#   'Country': 'RU',
#   'Date': 1712783733},
#  {'City': 'mwinilunga',
#   'Lat': -11.7358,
#   'Lng': 24.4293,
#   'Max Temp': 18.53,
#   'Humidity': 96,
#   'Cloudiness': 100,
#   'Wind Speed': 1.15,
#   'Country': 'ZM',
#   'Date': 1712783733},
#  {'City': 'binhe',
#   'Lat': 32.6883,
#   'Lng': 112.8275,
#   'Max Temp': 13.01,
#   'Humidity': 94,
#   'Cloudiness': 76,
#   'Wind Speed': 2.82,
#   'Country': 'CN',
#   'Date': 1712783733},
#  {'City': "ust'-ordynskiy",
#   'Lat': 52.805,
#   'Lng': 104.7508,
#   'Max Temp': 2.96,
#   'Humidity': 97,
#   'Cloudiness': 100,
#   'Wind Speed': 1.4,
#   'Country': 'RU',
#   'Date': 1712783733},
#  {'City': 'vorgashor',
#   'Lat': 67.5833,
#   'Lng': 63.95,
#   'Max Temp': -25.13,
#   'Humidity': 100,
#   'Cloudiness': 100,
#   'Wind Speed': 1.76,
#   'Country': 'RU',
#   'Date': 1712783734},
#  {'City': 'guerrero negro',
#   'Lat': 27.9769,
#   'Lng': -114.0611,
#   'Max Temp': 25.88,
#   'Humidity': 26,
#   'Cloudiness': 0,
#   'Wind Speed': 4.96,
#   'Country': 'MX',
#   'Date': 1712783734},
#  {'City': 'pontes e lacerda',
#   'Lat': -15.2261,
#   'Lng': -59.3353,
#   'Max Temp': 26.64,
#   'Humidity': 91,
#   'Cloudiness': 100,
#   'Wind Speed': 1.03,
#   'Country': 'BR',
#   'Date': 1712783601},
#  {'City': 'sao jose da coroa grande',
#   'Lat': -8.8978,
#   'Lng': -35.1478,
#   'Max Temp': 27.63,
#   'Humidity': 76,
#   'Cloudiness': 100,
#   'Wind Speed': 2.31,
#   'Country': 'BR',
#   'Date': 1712783564},
#  {'City': 'huarmey',
#   'Lat': -10.0681,
#   'Lng': -78.1522,
#   'Max Temp': 24.72,
#   'Humidity': 76,
#   'Cloudiness': 71,
#   'Wind Speed': 4.78,
#   'Country': 'PE',
#   'Date': 1712783436},
#  {'City': 'ancud',
#   'Lat': -41.8697,
#   'Lng': -73.8203,
#   'Max Temp': 13.87,
#   'Humidity': 57,
#   'Cloudiness': 0,
#   'Wind Speed': 1.82,
#   'Country': 'CL',
#   'Date': 1712783734},
#  {'City': 'alexandria',
#   'Lat': 31.2156,
#   'Lng': 29.9553,
#   'Max Temp': 18.12,
#   'Humidity': 72,
#   'Cloudiness': 6,
#   'Wind Speed': 2.74,
#   'Country': 'EG',
#   'Date': 1712783713},
#  {'City': 'tosno',
#   'Lat': 59.54,
#   'Lng': 30.8775,
#   'Max Temp': 11.58,
#   'Humidity': 67,
#   'Cloudiness': 100,
#   'Wind Speed': 5.29,
#   'Country': 'RU',
#   'Date': 1712783735},
#  {'City': 'mount pearl',
#   'Lat': 47.5166,
#   'Lng': -52.7813,
#   'Max Temp': -0.08,
#   'Humidity': 82,
#   'Cloudiness': 75,
#   'Wind Speed': 4.63,
#   'Country': 'CA',
#   'Date': 1712783735},
#  {'City': 'caruthersville',
#   'Lat': 36.1931,
#   'Lng': -89.6556,
#   'Max Temp': 20.97,
#   'Humidity': 91,
#   'Cloudiness': 100,
#   'Wind Speed': 3.25,
#   'Country': 'US',
#   'Date': 1712783735},
#  {'City': 'khorramabad',
#   'Lat': 33.4878,
#   'Lng': 48.3558,
#   'Max Temp': 11.27,
#   'Humidity': 76,
#   'Cloudiness': 85,
#   'Wind Speed': 2.2,
#   'Country': 'IR',
#   'Date': 1712783735},
#  {'City': 'laojunmiao',
#   'Lat': 39.8333,
#   'Lng': 97.7333,
#   'Max Temp': 8.97,
#   'Humidity': 20,
#   'Cloudiness': 67,
#   'Wind Speed': 3.97,
#   'Country': 'CN',
#   'Date': 1712783735},
#  {'City': 'comodoro rivadavia',
#   'Lat': -45.8667,
#   'Lng': -67.5,
#   'Max Temp': 11.92,
#   'Humidity': 43,
#   'Cloudiness': 0,
#   'Wind Speed': 3.6,
#   'Country': 'AR',
#   'Date': 1712783704},
#  {'City': 'kodiak',
#   'Lat': 57.79,
#   'Lng': -152.4072,
#   'Max Temp': 1.73,
#   'Humidity': 64,
#   'Cloudiness': 75,
#   'Wind Speed': 6.17,
#   'Country': 'US',
#   'Date': 1712783735},
#  {'City': 'ryotsu-minato',
#   'Lat': 38.0833,
#   'Lng': 138.4333,
#   'Max Temp': 6.76,
#   'Humidity': 59,
#   'Cloudiness': 36,
#   'Wind Speed': 0.91,
#   'Country': 'JP',
#   'Date': 1712783736},
#  {'City': 'ceeldheer',
#   'Lat': 3.8488,
#   'Lng': 47.1806,
#   'Max Temp': 28.59,
#   'Humidity': 71,
#   'Cloudiness': 8,
#   'Wind Speed': 6.48,
#   'Country': 'SO',
#   'Date': 1712783736},
#  {'City': 'port lincoln',
#   'Lat': -34.7333,
#   'Lng': 135.8667,
#   'Max Temp': 14.79,
#   'Humidity': 77,
#   'Cloudiness': 66,
#   'Wind Speed': 4.06,
#   'Country': 'AU',
#   'Date': 1712783736},
#  {'City': 'tevriz',
#   'Lat': 57.509,
#   'Lng': 72.4042,
#   'Max Temp': -4.83,
#   'Humidity': 88,
#   'Cloudiness': 99,
#   'Wind Speed': 1.33,
#   'Country': 'RU',
#   'Date': 1712783736},
#  {'City': "medvezh'yegorsk",
#   'Lat': 62.9167,
#   'Lng': 34.4667,
#   'Max Temp': 5.3,
#   'Humidity': 100,
#   'Cloudiness': 100,
#   'Wind Speed': 2.76,
#   'Country': 'RU',
#   'Date': 1712783736},
#  {'City': 'rusape',
#   'Lat': -18.5278,
#   'Lng': 32.1284,
#   'Max Temp': 18.14,
#   'Humidity': 93,
#   'Cloudiness': 100,
#   'Wind Speed': 2.05,
#   'Country': 'ZW',
#   'Date': 1712783736},
#  {'City': 'hammerfest',
#   'Lat': 70.6634,
#   'Lng': 23.6821,
#   'Max Temp': 3.25,
#   'Humidity': 87,
#   'Cloudiness': 75,
#   'Wind Speed': 3.09,
#   'Country': 'NO',
#   'Date': 1712783736},
#  {'City': 'mbaiki',
#   'Lat': 3.8678,
#   'Lng': 17.9892,
#   'Max Temp': 26.2,
#   'Humidity': 59,
#   'Cloudiness': 96,
#   'Wind Speed': 0.99,
#   'Country': 'CF',
#   'Date': 1712783736},
#  {'City': 'nampula',
#   'Lat': -15.1165,
#   'Lng': 39.2666,
#   'Max Temp': 22.88,
#   'Humidity': 86,
#   'Cloudiness': 98,
#   'Wind Speed': 1.61,
#   'Country': 'MZ',
#   'Date': 1712783736},
#  {'City': 'leer',
#   'Lat': 53.2316,
#   'Lng': 7.461,
#   'Max Temp': 10.52,
#   'Humidity': 75,
#   'Cloudiness': 79,
#   'Wind Speed': 3.93,
#   'Country': 'DE',
#   'Date': 1712783737},
#  {'City': 'capdepera',
#   'Lat': 39.7026,
#   'Lng': 3.4336,
#   'Max Temp': 11.98,
#   'Humidity': 66,
#   'Cloudiness': 0,
#   'Wind Speed': 1.53,
#   'Country': 'ES',
#   'Date': 1712783737},
#  {'City': 'punta arenas',
#   'Lat': -53.15,
#   'Lng': -70.9167,
#   'Max Temp': 9.06,
#   'Humidity': 66,
#   'Cloudiness': 75,
#   'Wind Speed': 8.23,
#   'Country': 'CL',
#   'Date': 1712783737},
#  {'City': 'thompson',
#   'Lat': 55.7435,
#   'Lng': -97.8558,
#   'Max Temp': 1.06,
#   'Humidity': 100,
#   'Cloudiness': 100,
#   'Wind Speed': 2.24,
#   'Country': 'CA',
#   'Date': 1712783666},
#  {'City': 'kenai',
#   'Lat': 60.5544,
#   'Lng': -151.2583,
#   'Max Temp': 2.05,
#   'Humidity': 80,
#   'Cloudiness': 40,
#   'Wind Speed': 1.54,
#   'Country': 'US',
#   'Date': 1712783737},
#  {'City': 'paracuru',
#   'Lat': -3.41,
#   'Lng': -39.0306,
#   'Max Temp': 28.39,
#   'Humidity': 83,
#   'Cloudiness': 100,
#   'Wind Speed': 3.46,
#   'Country': 'BR',
#   'Date': 1712783737},
#  {'City': 'quixeramobim',
#   'Lat': -5.1992,
#   'Lng': -39.2928,
#   'Max Temp': 24.67,
#   'Humidity': 95,
#   'Cloudiness': 100,
#   'Wind Speed': 1.78,
#   'Country': 'BR',
#   'Date': 1712783737},
#  {'City': 'kayangel',
#   'Lat': 8.0823,
#   'Lng': 134.7173,
#   'Max Temp': 27.93,
#   'Humidity': 77,
#   'Cloudiness': 75,
#   'Wind Speed': 5.6,
#   'Country': 'PW',
#   'Date': 1712783737},
#  {'City': 'bonthe',
#   'Lat': 7.5264,
#   'Lng': -12.505,
#   'Max Temp': 26.16,
#   'Humidity': 86,
#   'Cloudiness': 62,
#   'Wind Speed': 3.2,
#   'Country': 'SL',
#   'Date': 1712783738},
#  {'City': 'tomatlan',
#   'Lat': 19.9333,
#   'Lng': -105.25,
#   'Max Temp': 30.09,
#   'Humidity': 39,
#   'Cloudiness': 8,
#   'Wind Speed': 4.3,
#   'Country': 'MX',
#   'Date': 1712783738},
#  {'City': 'manokwari',
#   'Lat': -0.8667,
#   'Lng': 134.0833,
#   'Max Temp': 25.26,
#   'Humidity': 86,
#   'Cloudiness': 100,
#   'Wind Speed': 3.64,
#   'Country': 'ID',
#   'Date': 1712783738},
#  {'City': 'pamandzi',
#   'Lat': -12.7967,
#   'Lng': 45.2794,
#   'Max Temp': 28.88,
#   'Humidity': 84,
#   'Cloudiness': 40,
#   'Wind Speed': 2.06,
#   'Country': 'YT',
#   'Date': 1712783738},
#  {'City': 'ulety',
#   'Lat': 51.3572,
#   'Lng': 112.4849,
#   'Max Temp': 4.32,
#   'Humidity': 86,
#   'Cloudiness': 98,
#   'Wind Speed': 1.03,
#   'Country': 'RU',
#   'Date': 1712783738},
#  {'City': 'katsuren-haebaru',
#   'Lat': 26.3369,
#   'Lng': 127.8719,
#   'Max Temp': 21.01,
#   'Humidity': 84,
# ...
#   'Max Temp': 19.93,
#   'Humidity': 98,
#   'Cloudiness': 100,
#   'Wind Speed': 1.79,
#   'Country': 'ZM',
#   'Date': 1712783766},
#  {'City': 'east london',
#   'Lat': -33.0153,
#   'Lng': 27.9116,
#   'Max Temp': 17.19,
#   'Humidity': 73,
#   'Cloudiness': 100,
#   'Wind Speed': 8.5,
#   'Country': 'ZA',
#   'Date': 1712783712},
#  {'City': 'undurkhaan',
#   'Lat': 47.3194,
#   'Lng': 110.6556,
#   'Max Temp': 8.46,
#   'Humidity': 43,
#   'Cloudiness': 71,
#   'Wind Speed': 3.11,
#   'Country': 'MN',
#   'Date': 1712783767},
#  {'City': 'gereshk',
#   'Lat': 31.8209,
#   'Lng': 64.5701,
#   'Max Temp': 21.67,
#   'Humidity': 21,
#   'Cloudiness': 5,
#   'Wind Speed': 1.6,
#   'Country': 'AF',
#   'Date': 1712783767},
#  {'City': 'hirado',
#   'Lat': 33.3597,
#   'Lng': 129.5531,
#   'Max Temp': 10.77,
#   'Humidity': 81,
#   'Cloudiness': 99,
#   'Wind Speed': 1.83,
#   'Country': 'JP',
#   'Date': 1712783767},
#  {'City': 'zaragoza',
#   'Lat': 41.6561,
#   'Lng': -0.8773,
#   'Max Temp': 14.45,
#   'Humidity': 37,
#   'Cloudiness': 0,
#   'Wind Speed': 13.38,
#   'Country': 'ES',
#   'Date': 1712783602},
#  {'City': 'crane',
#   'Lat': 31.3974,
#   'Lng': -102.3501,
#   'Max Temp': 21.83,
#   'Humidity': 18,
#   'Cloudiness': 0,
#   'Wind Speed': 9.02,
#   'Country': 'US',
#   'Date': 1712783767},
#  {'City': 'torrevieja',
#   'Lat': 37.9787,
#   'Lng': -0.6822,
#   'Max Temp': 17.32,
#   'Humidity': 56,
#   'Cloudiness': 0,
#   'Wind Speed': 2.58,
#   'Country': 'ES',
#   'Date': 1712783606},
#  {'City': 'matoury',
#   'Lat': 4.8483,
#   'Lng': -52.3317,
#   'Max Temp': 28.98,
#   'Humidity': 84,
#   'Cloudiness': 75,
#   'Wind Speed': 4.63,
#   'Country': 'GF',
#   'Date': 1712783767},
#  {'City': 'santa rosa',
#   'Lat': 14.3122,
#   'Lng': 121.1114,
#   'Max Temp': 27.84,
#   'Humidity': 80,
#   'Cloudiness': 84,
#   'Wind Speed': 4.59,
#   'Country': 'PH',
#   'Date': 1712783767},
#  {'City': 'izhmorskiy',
#   'Lat': 56.194,
#   'Lng': 86.6414,
#   'Max Temp': -5.43,
#   'Humidity': 89,
#   'Cloudiness': 85,
#   'Wind Speed': 2.35,
#   'Country': 'RU',
#   'Date': 1712783768},
#  {'City': 'afif',
#   'Lat': 23.9065,
#   'Lng': 42.9172,
#   'Max Temp': 22.62,
#   'Humidity': 24,
#   'Cloudiness': 73,
#   'Wind Speed': 3.27,
#   'Country': 'SA',
#   'Date': 1712783768},
#  {'City': 'boende',
#   'Lat': -0.2167,
#   'Lng': 20.8667,
#   'Max Temp': 22.64,
#   'Humidity': 95,
#   'Cloudiness': 100,
#   'Wind Speed': 0.72,
#   'Country': 'CD',
#   'Date': 1712783768},
#  {'City': 'rio grande',
#   'Lat': -32.035,
#   'Lng': -52.0986,
#   'Max Temp': 22.06,
#   'Humidity': 81,
#   'Cloudiness': 100,
#   'Wind Speed': 9.24,
#   'Country': 'BR',
#   'Date': 1712783313},
#  {'City': 'palikir - national government center',
#   'Lat': 6.9248,
#   'Lng': 158.1611,
#   'Max Temp': 27.41,
#   'Humidity': 89,
#   'Cloudiness': 100,
#   'Wind Speed': 3.6,
#   'Country': 'FM',
#   'Date': 1712783768},
#  {'City': 'huaiyuan chengguanzhen',
#   'Lat': 32.9589,
#   'Lng': 117.1657,
#   'Max Temp': 14.68,
#   'Humidity': 96,
#   'Cloudiness': 100,
#   'Wind Speed': 1.92,
#   'Country': 'CN',
#   'Date': 1712783768},
#  {'City': 'fort bragg',
#   'Lat': 35.139,
#   'Lng': -79.006,
#   'Max Temp': 26.08,
#   'Humidity': 51,
#   'Cloudiness': 75,
#   'Wind Speed': 5.14,
#   'Country': 'US',
#   'Date': 1712783544},
#  {'City': 'khunti',
#   'Lat': 23.0833,
#   'Lng': 85.2833,
#   'Max Temp': 24.06,
#   'Humidity': 33,
#   'Cloudiness': 100,
#   'Wind Speed': 2.79,
#   'Country': 'IN',
#   'Date': 1712783769},
#  {'City': 'grants pass',
#   'Lat': 42.439,
#   'Lng': -123.3284,
#   'Max Temp': 22.67,
#   'Humidity': 41,
#   'Cloudiness': 0,
#   'Wind Speed': 1.54,
#   'Country': 'US',
#   'Date': 1712783665},
#  {'City': 'mount isa',
#   'Lat': -20.7333,
#   'Lng': 139.5,
#   'Max Temp': 15.87,
#   'Humidity': 41,
#   'Cloudiness': 13,
#   'Wind Speed': 4.63,
#   'Country': 'AU',
#   'Date': 1712783769},
#  {'City': 'zhanaozen',
#   'Lat': 43.3,
#   'Lng': 52.8,
#   'Max Temp': 16.35,
#   'Humidity': 38,
#   'Cloudiness': 98,
#   'Wind Speed': 4.24,
#   'Country': 'KZ',
#   'Date': 1712783769},
#  {'City': 'aragarcas',
#   'Lat': -15.8975,
#   'Lng': -52.2508,
#   'Max Temp': 26.17,
#   'Humidity': 81,
#   'Cloudiness': 62,
#   'Wind Speed': 1.91,
#   'Country': 'BR',
#   'Date': 1712783769},
#  {'City': 'mont-tremblant',
#   'Lat': 46.1949,
#   'Lng': -74.6264,
#   'Max Temp': 12.98,
#   'Humidity': 74,
#   'Cloudiness': 90,
#   'Wind Speed': 2.07,
#   'Country': 'CA',
#   'Date': 1712783610},
#  {'City': 'valparaiso',
#   'Lat': -33.0393,
#   'Lng': -71.6273,
#   'Max Temp': 23.97,
#   'Humidity': 72,
#   'Cloudiness': 75,
#   'Wind Speed': 4.63,
#   'Country': 'CL',
#   'Date': 1712783512},
#  {'City': 'ouesso',
#   'Lat': 1.6136,
#   'Lng': 16.0517,
#   'Max Temp': 21.76,
#   'Humidity': 91,
#   'Cloudiness': 97,
#   'Wind Speed': 1.01,
#   'Country': 'CG',
#   'Date': 1712783769},
#  {'City': 'selkirk',
#   'Lat': 50.1436,
#   'Lng': -96.8845,
#   'Max Temp': 13.38,
#   'Humidity': 75,
#   'Cloudiness': 100,
#   'Wind Speed': 4.44,
#   'Country': 'CA',
#   'Date': 1712783770},
#  {'City': "ves'yegonsk",
#   'Lat': 58.664,
#   'Lng': 37.2604,
#   'Max Temp': 13.58,
#   'Humidity': 88,
#   'Cloudiness': 100,
#   'Wind Speed': 4.62,
#   'Country': 'RU',
#   'Date': 1712783770},
#  {'City': "ma'an",
#   'Lat': 26.9775,
#   'Lng': 110.7211,
#   'Max Temp': 17.8,
#   'Humidity': 91,
#   'Cloudiness': 100,
#   'Wind Speed': 1.04,
#   'Country': 'CN',
#   'Date': 1712783770},
#  {'City': 'kilju',
#   'Lat': 40.9642,
#   'Lng': 129.3278,
#   'Max Temp': 9.58,
#   'Humidity': 68,
#   'Cloudiness': 100,
#   'Wind Speed': 0.25,
#   'Country': 'KP',
#   'Date': 1712783770},
#  {'City': 'lakatoro',
#   'Lat': -16.0999,
#   'Lng': 167.4164,
#   'Max Temp': 27.8,
#   'Humidity': 82,
#   'Cloudiness': 68,
#   'Wind Speed': 0.9,
#   'Country': 'VU',
#   'Date': 1712783770},
#  {'City': 'shortandy',
#   'Lat': 51.7006,
#   'Lng': 70.9994,
#   'Max Temp': 0.17,
#   'Humidity': 84,
#   'Cloudiness': 58,
#   'Wind Speed': 5.64,
#   'Country': 'KZ',
#   'Date': 1712783770},
#  {'City': 'labrador city',
#   'Lat': 52.9463,
#   'Lng': -66.9114,
#   'Max Temp': 1.66,
#   'Humidity': 60,
#   'Cloudiness': 8,
#   'Wind Speed': 3.11,
#   'Country': 'CA',
#   'Date': 1712783487},
#  {'City': 'el porvenir',
#   'Lat': 13.7617,
#   'Lng': -87.3458,
#   'Max Temp': 34.63,
#   'Humidity': 25,
#   'Cloudiness': 100,
#   'Wind Speed': 2.46,
#   'Country': 'HN',
#   'Date': 1712783770},
#  {'City': 'mugia',
#   'Lat': 43.1041,
#   'Lng': -9.2179,
#   'Max Temp': 14.95,
#   'Humidity': 72,
#   'Cloudiness': 100,
#   'Wind Speed': 5.3,
#   'Country': 'ES',
#   'Date': 1712783563},
#  {'City': 'hamada',
#   'Lat': 34.8833,
#   'Lng': 132.0833,
#   'Max Temp': 11.56,
#   'Humidity': 74,
#   'Cloudiness': 100,
#   'Wind Speed': 2.75,
#   'Country': 'JP',
#   'Date': 1712783771},
#  {'City': 'biloela',
#   'Lat': -24.4167,
#   'Lng': 150.5,
#   'Max Temp': 14.02,
#   'Humidity': 59,
#   'Cloudiness': 0,
#   'Wind Speed': 2.73,
#   'Country': 'AU',
#   'Date': 1712783771},
#  {'City': "'ain el turk",
#   'Lat': 35.7438,
#   'Lng': -0.7693,
#   'Max Temp': 15.38,
#   'Humidity': 44,
#   'Cloudiness': 0,
#   'Wind Speed': 2.06,
#   'Country': 'DZ',
#   'Date': 1712783771},
#  {'City': 'beau vallon',
#   'Lat': -20.4189,
#   'Lng': 57.6953,
#   'Max Temp': 26.23,
#   'Humidity': 82,
#   'Cloudiness': 51,
#   'Wind Speed': 4.86,
#   'Country': 'MU',
#   'Date': 1712783559},
#  {'City': 'zaysan',
#   'Lat': 47.4667,
#   'Lng': 84.8667,
#   'Max Temp': 7.05,
#   'Humidity': 95,
#   'Cloudiness': 100,
#   'Wind Speed': 3.83,
#   'Country': 'KZ',
#   'Date': 1712783771},
#  {'City': 'quelimane',
#   'Lat': -17.8786,
#   'Lng': 36.8883,
#   'Max Temp': 27.19,
#   'Humidity': 91,
#   'Cloudiness': 93,
#   'Wind Speed': 2.66,
#   'Country': 'MZ',
#   'Date': 1712783771},
#  {'City': 'cannonvale',
#   'Lat': -20.2833,
#   'Lng': 148.7,
#   'Max Temp': 21.66,
#   'Humidity': 60,
#   'Cloudiness': 9,
#   'Wind Speed': 6.65,
#   'Country': 'AU',
#   'Date': 1712783771},
#  {'City': 'ambovombe',
#   'Lat': -25.1667,
#   'Lng': 46.0833,
#   'Max Temp': 24.04,
#   'Humidity': 83,
#   'Cloudiness': 66,
#   'Wind Speed': 4.64,
#   'Country': 'MG',
#   'Date': 1712783772},
#  {'City': 'okhotsk',
#   'Lat': 59.3833,
#   'Lng': 143.3,
#   'Max Temp': -6.74,
#   'Humidity': 70,
#   'Cloudiness': 3,
#   'Wind Speed': 5.96,
#   'Country': 'RU',
#   'Date': 1712783772},
#  {'City': 'ahar',
#   'Lat': 38.4774,
#   'Lng': 47.0699,
#   'Max Temp': 9.07,
#   'Humidity': 91,
#   'Cloudiness': 100,
#   'Wind Speed': 2.17,
#   'Country': 'IR',
#   'Date': 1712783772},
#  {'City': 'newark',
#   'Lat': 40.7357,
#   'Lng': -74.1724,
#   'Max Temp': 21.5,
#   'Humidity': 68,
#   'Cloudiness': 75,
#   'Wind Speed': 3.6,
#   'Country': 'US',
#   'Date': 1712783264},
#  {'City': 'kailua-kona',
#   'Lat': 19.6406,
#   'Lng': -155.9956,
#   'Max Temp': 26.98,
#   'Humidity': 84,
#   'Cloudiness': 40,
#   'Wind Speed': 5.66,
#   'Country': 'US',
#   'Date': 1712783608},
#  {'City': 'la palma',
#   'Lat': 33.8464,
#   'Lng': -118.0467,
#   'Max Temp': 32.15,
#   'Humidity': 39,
#   'Cloudiness': 0,
#   'Wind Speed': 4.12,
#   'Country': 'US',
#   'Date': 1712783772},
#  {'City': 'sarupathar',
#   'Lat': 26.1984,
#   'Lng': 93.8094,
#   'Max Temp': 21.67,
#   'Humidity': 54,
#   'Cloudiness': 100,
#   'Wind Speed': 1.26,
#   'Country': 'IN',
#   'Date': 1712783773},
#  {'City': 'mirnyy',
#   'Lat': 62.5353,
#   'Lng': 113.9611,
#   'Max Temp': -11.54,
#   'Humidity': 82,
#   'Cloudiness': 100,
#   'Wind Speed': 4.02,
#   'Country': 'RU',
#   'Date': 1712783773},
#  {'City': 'monrovia',
#   'Lat': 6.3005,
#   'Lng': -10.7969,
#   'Max Temp': 24.87,
#   'Humidity': 85,
#   'Cloudiness': 66,
#   'Wind Speed': 2.94,
#   'Country': 'LR',
#   'Date': 1712783773},
#  {'City': 'feodosiya',
#   'Lat': 45.0333,
#   'Lng': 35.3833,
#   'Max Temp': 12.96,
#   'Humidity': 74,
#   'Cloudiness': 82,
#   'Wind Speed': 4.51,
#   'Country': 'UA',
#   'Date': 1712783773},
#  {'City': 'camabatela',
#   'Lat': -8.1881,
#   'Lng': 15.375,
#   'Max Temp': 18.33,
#   'Humidity': 97,
#   'Cloudiness': 99,
#   'Wind Speed': 0.93,
#   'Country': 'AO',
#   'Date': 1712783773},
#  {'City': 'nelsonville',
#   'Lat': 39.4587,
#   'Lng': -82.2318,
#   'Max Temp': 18.15,
#   'Humidity': 85,
#   'Cloudiness': 100,
#   'Wind Speed': 2.13,
#   'Country': 'US',
#   'Date': 1712783773},
#  {'City': 'kidal',
#   'Lat': 18.4411,
#   'Lng': 1.4078,
#   'Max Temp': 33.23,
#   'Humidity': 9,
#   'Cloudiness': 12,
#   'Wind Speed': 4.83,
#   'Country': 'ML',
#   'Date': 1712783773},
#  {'City': 'takoradi',
#   'Lat': 4.8845,
#   'Lng': -1.7554,
#   'Max Temp': 28.81,
#   'Humidity': 81,
#   'Cloudiness': 100,
#   'Wind Speed': 4.42,
#   'Country': 'GH',
#   'Date': 1712783773},
#  {'City': 'concordia',
#   'Lat': -31.393,
#   'Lng': -58.0209,
#   'Max Temp': 20.44,
#   'Humidity': 75,
#   'Cloudiness': 75,
#   'Wind Speed': 6.69,
#   'Country': 'AR',
#   'Date': 1712783748},
#  {'City': 'bam',
#   'Lat': 29.106,
#   'Lng': 58.357,
#   'Max Temp': 25.42,
#   'Humidity': 27,
#   'Cloudiness': 66,
#   'Wind Speed': 2.24,
#   'Country': 'IR',
#   'Date': 1712783774},
#  {'City': 'panchkula',
#   'Lat': 30.6975,
#   'Lng': 76.8551,
#   'Max Temp': 25.64,
#   'Humidity': 15,
#   'Cloudiness': 74,
#   'Wind Speed': 4.8,
#   'Country': 'IN',
#   'Date': 1712783774},
#  {'City': 'wanxian',
#   'Lat': 30.8039,
#   'Lng': 108.3897,
#   'Max Temp': 15.61,
#   'Humidity': 95,
#   'Cloudiness': 96,
#   'Wind Speed': 1.57,
#   'Country': 'CN',
#   'Date': 1712783774},
#  {'City': 'novo aripuana',
#   'Lat': -5.1206,
#   'Lng': -60.3797,
#   'Max Temp': 29.93,
#   'Humidity': 76,
#   'Cloudiness': 72,
#   'Wind Speed': 0.72,
#   'Country': 'BR',
#   'Date': 1712783774},
#  {'City': 'taroa',
#   'Lat': 8.7058,
#   'Lng': 171.2275,
#   'Max Temp': 27.36,
#   'Humidity': 83,
#   'Cloudiness': 99,
#   'Wind Speed': 9.19,
#   'Country': 'MH',
#   'Date': 1712783774},
#  {'City': 'phuthaditjhaba',
#   'Lat': -28.5242,
#   'Lng': 28.8158,
#   'Max Temp': 9.74,
#   'Humidity': 86,
#   'Cloudiness': 1,
#   'Wind Speed': 2.11,
#   'Country': 'ZA',
#   'Date': 1712783774},
#  {'City': 'noshiro',
#   'Lat': 40.2039,
#   'Lng': 140.0242,
#   'Max Temp': 3.65,
#   'Humidity': 68,
#   'Cloudiness': 34,
#   'Wind Speed': 2.76,
#   'Country': 'JP',
#   'Date': 1712783774},
#  {'City': 'kokpekty',
#   'Lat': 48.75,
#   'Lng': 82.4,
#   'Max Temp': 3.97,
#   'Humidity': 96,
#   'Cloudiness': 100,
#   'Wind Speed': 0.99,
#   'Country': 'KZ',
#   'Date': 1712783774},
#  {'City': 'kone',
#   'Lat': -21.0595,
#   'Lng': 164.8658,
#   'Max Temp': 25.33,
#   'Humidity': 90,
#   'Cloudiness': 97,
#   'Wind Speed': 1.66,
#   'Country': 'NC',
#   'Date': 1712783774},
#  {'City': 'thinadhoo',
#   'Lat': 0.5333,
#   'Lng': 72.9333,
#   'Max Temp': 29.53,
#   'Humidity': 73,
#   'Cloudiness': 94,
#   'Wind Speed': 4.47,
#   'Country': 'MV',
#   'Date': 1712783775},
#  {'City': 'abbiategrasso',
#   'Lat': 45.4008,
#   'Lng': 8.9185,
#   'Max Temp': 12.81,
#   'Humidity': 90,
#   'Cloudiness': 100,
#   'Wind Speed': 0.89,
#   'Country': 'IT',
#   'Date': 1712783775},
#  {'City': 'anicuns',
#   'Lat': -16.4611,
#   'Lng': -49.9617,
#   'Max Temp': 22.02,
#   'Humidity': 88,
#   'Cloudiness': 86,
#   'Wind Speed': 1.55,
#   'Country': 'BR',
#   'Date': 1712783775},
#  {'City': 'taoudenni',
#   'Lat': 22.6783,
#   'Lng': -3.9836,
#   'Max Temp': 34.74,
#   'Humidity': 10,
#   'Cloudiness': 0,
#   'Wind Speed': 2.96,
#   'Country': 'ML',
#   'Date': 1712783775},
#  {'City': 'salekhard',
#   'Lat': 66.53,
#   'Lng': 66.6019,
#   'Max Temp': -28.67,
#   'Humidity': 100,
#   'Cloudiness': 74,
#   'Wind Speed': 0.48,
#   'Country': 'RU',
#   'Date': 1712783775},
#  {'City': 'mazatlan',
#   'Lat': 23.2167,
#   'Lng': -106.4167,
#   'Max Temp': 26.98,
#   'Humidity': 60,
#   'Cloudiness': 20,
#   'Wind Speed': 4.12,
#   'Country': 'MX',
#   'Date': 1712783561},
#  {'City': 'fort st. john',
#   'Lat': 56.2499,
#   'Lng': -120.8529,
#   'Max Temp': 8.46,
#   'Humidity': 28,
#   'Cloudiness': 100,
#   'Wind Speed': 5.17,
#   'Country': 'CA',
#   'Date': 1712783600},
#  {'City': 'ta`u',
#   'Lat': -14.2336,
#   'Lng': -169.5144,
#   'Max Temp': 29.13,
#   'Humidity': 78,
#   'Cloudiness': 8,
#   'Wind Speed': 4.55,
#   'Country': 'AS',
#   'Date': 1712783776},
#  {'City': 'aleksandrovsk-sakhalinskiy',
#   'Lat': 50.8975,
#   'Lng': 142.1561,
#   'Max Temp': -1.91,
#   'Humidity': 75,
#   'Cloudiness': 56,
#   'Wind Speed': 7.22,
#   'Country': 'RU',
#   'Date': 1712783776},
#  {'City': 'el granada',
#   'Lat': 37.5027,
#   'Lng': -122.4694,
#   'Max Temp': 28.78,
#   'Humidity': 70,
#   'Cloudiness': 75,
#   'Wind Speed': 2.24,
#   'Country': 'US',
#   'Date': 1712783776},
#  {'City': 'fernandopolis',
#   'Lat': -20.2839,
#   'Lng': -50.2464,
#   'Max Temp': 25.28,
#   'Humidity': 75,
#   'Cloudiness': 72,
#   'Wind Speed': 2.02,
#   'Country': 'BR',
#   'Date': 1712783776},
#  {'City': 'ujae',
#   'Lat': 8.9322,
#   'Lng': 165.7642,
#   'Max Temp': 27.56,
#   'Humidity': 80,
#   'Cloudiness': 100,
#   'Wind Speed': 9.99,
#   'Country': 'MH',
#   'Date': 1712783776},
#  {'City': 'broome',
#   'Lat': 42.2506,
#   'Lng': -75.833,
#   'Max Temp': 15.81,
#   'Humidity': 88,
#   'Cloudiness': 100,
#   'Wind Speed': 2.68,
#   'Country': 'US',
#   'Date': 1712783776},
#  {'City': 'geraldton',
#   'Lat': -28.7667,
#   'Lng': 114.6,
#   'Max Temp': 24.23,
#   'Humidity': 33,
#   'Cloudiness': 100,
#   'Wind Speed': 3.09,
#   'Country': 'AU',
#   'Date': 1712783776},
#  {'City': 'tarko-sale',
#   'Lat': 64.9225,
#   'Lng': 77.785,
#   'Max Temp': -30.82,
#   'Humidity': 100,
#   'Cloudiness': 23,
#   'Wind Speed': 2.26,
#   'Country': 'RU',
#   'Date': 1712783777},
#  {'City': 'island harbour',
#   'Lat': 50.724,
#   'Lng': -1.2758,
#   'Max Temp': 12.24,
#   'Humidity': 94,
#   'Cloudiness': 100,
#   'Wind Speed': 4.02,
#   'Country': 'GB',
#   'Date': 1712783777},
#  {'City': 'argostolion',
#   'Lat': 38.1811,
#   'Lng': 20.489,
#   'Max Temp': 18.19,
#   'Humidity': 31,
#   'Cloudiness': 100,
#   'Wind Speed': 0.67,
#   'Country': 'GR',
#   'Date': 1712783570},
#  {'City': 'alesund',
#   'Lat': 62.4723,
#   'Lng': 6.1549,
#   'Max Temp': 6.51,
#   'Humidity': 75,
#   'Cloudiness': 20,
#   'Wind Speed': 6.69,
#   'Country': 'NO',
#   'Date': 1712783777},
#  {'City': 'berbera',
#   'Lat': 10.4396,
#   'Lng': 45.0143,
#   'Max Temp': 27.81,
#   'Humidity': 80,
#   'Cloudiness': 33,
#   'Wind Speed': 1.47,
#   'Country': 'SO',
#   'Date': 1712783777},
#  {'City': 'tome acu',
#   'Lat': -2.4189,
#   'Lng': -48.1522,
#   'Max Temp': 26.12,
#   'Humidity': 96,
#   'Cloudiness': 77,
#   'Wind Speed': 1.29,
#   'Country': 'BR',
#   'Date': 1712783777},
#  {'City': 'kingscliff',
#   'Lat': -28.2667,
#   'Lng': 153.5667,
#   'Max Temp': 17.89,
#   'Humidity': 59,
#   'Cloudiness': 0,
#   'Wind Speed': 4.12,
#   'Country': 'AU',
#   'Date': 1712783777},
#  {'City': 'faya-largeau',
#   'Lat': 17.9257,
#   'Lng': 19.1043,
#   'Max Temp': 27.6,
#   'Humidity': 12,
#   'Cloudiness': 11,
#   'Wind Speed': 5.89,
#   'Country': 'TD',
#   'Date': 1712783777},
#  {'City': 'barreirinha',
#   'Lat': -2.7933,
#   'Lng': -57.07,
#   'Max Temp': 28.44,
#   'Humidity': 83,
#   'Cloudiness': 50,
#   'Wind Speed': 1.23,
#   'Country': 'BR',
#   'Date': 1712783778}]

# %%
# Convert the cities weather data into a Pandas DataFrame
city_data_df = pd.DataFrame(city_data)

# Show Record Count
city_data_df.count()
# Out:
# City          567
# Lat           567
# Lng           567
# Max Temp      567
# Humidity      567
# Cloudiness    567
# Wind Speed    567
# Country       567
# Date          567
# dtype: int64

# %%
city_data_df
# Out:
#                City      Lat       Lng  Max Temp  Humidity  Cloudiness  \
# 0          afaahiti -17.7500 -149.2833     29.93        82         100
# 1         papatowai -46.5619  169.4708     12.01       100         100
# 2           aasiaat  68.7098  -52.8699     -7.19        78         100
# 3             lhasa  29.6500   91.1000      2.13        68          86
# 4    port elizabeth -33.9180   25.5701     15.17        85         100
# ..              ...      ...       ...       ...       ...         ...
# 562         berbera  10.4396   45.0143     27.81        80          33
# 563        tome acu  -2.4189  -48.1522     26.12        96          77
# 564      kingscliff -28.2667  153.5667     17.89        59           0
# 565    faya-largeau  17.9257   19.1043     27.60        12          11
# 566     barreirinha  -2.7933  -57.0700     28.44        83          50
#
#      Wind Speed Country        Date
# 0          8.10      PF  1712783702
# 1          2.62      NZ  1712783702
# 2          2.59      GL  1712783703
# 3          1.18      CN  1712783703
# 4          1.34      ZA  1712783704
# ..          ...     ...         ...
# 562        1.47      SO  1712783777
# 563        1.29      BR  1712783777
# 564        4.12      AU  1712783777
# 565        5.89      TD  1712783777
# 566        1.23      BR  1712783778
#
# [567 rows x 9 columns]

# %%
# Display sample data
city_data_df.head()

# %%
# Export the City_Data into a csv
city_data_df.to_csv("output_data/cities.csv", index_label="City_ID")

# %%
# Read saved data
city_data_df = pd.read_csv("output_data/cities.csv", index_col="City_ID")

# Display sample data
city_data_df.head()

# %% [markdown]
# ### Create the Scatter Plots Requested
#
# #### Latitude Vs. Temperature

# %%
# Build scatter plot for latitude vs. temperature
# YOUR CODE HERE

# Incorporate the other graph properties
# YOUR CODE HERE

# Save the figure
plt.savefig("output_data/Fig1.png")

# Show plot
plt.show()

# %% [markdown]
# #### Latitude Vs. Humidity

# %%
# Build the scatter plots for latitude vs. humidity
# YOUR CODE HERE

# Incorporate the other graph properties
# YOUR CODE HERE

# Save the figure
plt.savefig("output_data/Fig2.png")

# Show plot
plt.show()

# %% [markdown]
# #### Latitude Vs. Cloudiness

# %%
# Build the scatter plots for latitude vs. cloudiness
# YOUR CODE HERE

# Incorporate the other graph properties
# YOUR CODE HERE

# Save the figure
plt.savefig("output_data/Fig3.png")

# Show plot
plt.show()

# %% [markdown]
# #### Latitude vs. Wind Speed Plot

# %%
# Build the scatter plots for latitude vs. wind speed
# YOUR CODE HERE

# Incorporate the other graph properties
# YOUR CODE HERE

# Save the figure
plt.savefig("output_data/Fig4.png")

# Show plot
plt.show()

# %% [markdown]
# ---
#
# ## Requirement 2: Compute Linear Regression for Each Relationship

# %%
# Define a function to create Linear Regression plots
# YOUR CODE HERE

# %%
# Create a DataFrame with the Northern Hemisphere data (Latitude >= 0)
# YOUR CODE HERE

# Display sample data
northern_hemi_df.head()

# %%
# Create a DataFrame with the Southern Hemisphere data (Latitude < 0)
# YOUR CODE HERE

# Display sample data
southern_hemi_df.head()

# %% [markdown]
# ###  Temperature vs. Latitude Linear Regression Plot

# %%
# Linear regression on Northern Hemisphere
# YOUR CODE HERE

# %%
# Linear regression on Southern Hemisphere
# YOUR CODE HERE

# %% [markdown]
# **Discussion about the linear relationship:** YOUR RESPONSE HERE

# %% [markdown]
# ### Humidity vs. Latitude Linear Regression Plot

# %%
# Northern Hemisphere
# YOUR CODE HERE

# %%
# Southern Hemisphere
# YOUR CODE HERE

# %% [markdown]
# **Discussion about the linear relationship:** YOUR RESPONSE HERE

# %% [markdown]
# ### Cloudiness vs. Latitude Linear Regression Plot

# %%
# Northern Hemisphere
# YOUR CODE HERE

# %%
# Southern Hemisphere
# YOUR CODE HERE

# %% [markdown]
# **Discussion about the linear relationship:** YOUR RESPONSE HERE

# %% [markdown]
# ### Wind Speed vs. Latitude Linear Regression Plot

# %%
# Northern Hemisphere
# YOUR CODE HERE

# %%
# Southern Hemisphere
# YOUR CODE HERE

# %% [markdown]
# **Discussion about the linear relationship:** YOUR RESPONSE HERE
